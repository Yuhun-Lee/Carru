# %%
# 거리 계산 함수
from geopy.distance import geodesic

def calculate_distance(lat1, long1, lat2, long2):
    return geodesic((lat1, long1), (lat2, long2)).km

# %%
# 무게와 거리를 고려한 단가 계산 함수 
import math

def calculate_shipping_cost(weight_class, distance):
    # 가격 테이블 (단위: 만 원)
    price_table = [
        [4, 5, 7, 8, 11, 13, 18, 20],  # 20km
        [5, 6, 8, 9, 12, 14, 19, 21],  # 30km
        [6, 7, 9, 10, 13, 15, 20, 22], # 50km
        [7, 8, 10, 11, 14, 17, 21, 23], # 70km
        [8, 9, 11, 12, 16, 19, 22, 25], # 90km
        [9, 10, 12, 13, 17, 20, 24, 27], # 110km
        [10, 11, 13, 14, 18, 21, 25, 28], # 130km
        [11, 12, 14, 15, 19, 23, 27, 30], # 150km
        [12, 13, 15, 16, 20, 25, 28, 31], # 170km
        [13, 14, 18, 19, 23, 27, 30, 32], # 200km
        [15, 16, 19, 20, 25, 33, 39, 42], # 250km
        [17, 18, 25, 26, 30, 37, 45, 48], # 300km
        [19, 20, 27, 28, 33, 38, 50, 53], # 350km
        [20, 21, 28, 30, 35, 42, 55, 58], # 400km
        [22, 23, 30, 32, 37, 44, 58, 62], # 450km
        [25, 26, 32, 34, 38, 46, 60, 64], # 500km
        [27, 28, 35, 37, 41, 48, 63, 67], # 550km
        [30, 31, 38, 40, 43, 50, 65, 70]  # 600km
    ]
    
    # 거리와 화물 무게에 대한 인덱스 계산
    distance_index = {
        20: 0, 30: 1, 50: 2, 70: 3, 90: 4,
        110: 5, 130: 6, 150: 7, 170: 8,
        200: 9, 250: 10, 300: 11, 350: 12,
        400: 13, 450: 14, 500: 15, 550: 16, 600: 17
    }
    
    # 화물 무게 클래스를 인덱스로 변환
    weight_index = {
        1: 0, 1.4: 1, 2.5: 2, 3.5: 3, 5: 4, 11: 5, 18: 6, 25: 7
    }
    
    # 거리와 화물 무게의 유효한 인덱스 찾기
    if distance not in distance_index:
        next_distance = min([d for d in distance_index.keys() if d > distance], default=None)
        if next_distance is not None:
            distance = next_distance
    
    if weight_class not in weight_index:
        next_weight = min([w for w in weight_index.keys() if w > weight_class], default=None)
        if next_weight is not None:
            weight_class = next_weight
            
    # 인덱스 얻기
    distance_index_value = distance_index.get(distance, len(price_table) - 1)
    weight_index_value = weight_index.get(weight_class, len(price_table[0]) - 1)
    
    # 가격 계산
    price = price_table[distance_index_value][weight_index_value]
    
    return price

# TEST example 
# weight_class = 25  # 화물 무게 (유효하지 않은 경우)
# distance = 700      # 거리 (유효하지 않은 경우)
# cost = calculate_shipping_cost(weight_class, distance)
# print(f"운송 비용: {cost} 만원")

# %%
def normalize(value, min_value, max_value):
    return (value - min_value) / (max_value - min_value)

# %% [markdown]
# ### 기사의 적합도 계산 함수
# -> 차고지 근처로 가는 1차 물류 매칭

# %%
def calculate_match_score(driver, logistics):
    # 1. 물류가 기사의 수용 무게 범위에 맞는지 확인
    if logistics['weight'] < driver['min_weight'] or logistics['weight'] > driver['max_weight']:
        return 0  # 물류가 적합하지 않으면 0점
    
    # 2. 기사의 출발지 ~ 물류 창고 간의 거리 계산
    distance_to_warehouse = calculate_distance(driver['departure_lat'], driver['departure_long'], logistics['departure_lat'], logistics['departure_long'])
    
    if distance_to_warehouse > 30: 
        return 0
    
    # 3. 물류 도착지와 기사의 차고지 간의 거리 계산
    distance_to_destination = calculate_distance(logistics['destination_lat'], logistics['destination_long'], driver['destination_lat'], driver['destination_long'])
    
    if distance_to_destination > 30: 
        return 0
    
    # 4. 물류 운송 거리 계산 
    distance_to_logistics = calculate_distance(logistics['departure_lat'], logistics['departure_long'], logistics['destination_lat'], logistics['destination_long'])
    
    # 5. 물류 가격 계산 (물류의 무게와 거리 기반)
    total_distance = distance_to_warehouse + distance_to_destination
    price = calculate_shipping_cost(logistics['weight'], distance_to_logistics)
    
    # 거리와 가격 정규화
    normalized_distance = normalize(total_distance, 2, 400) 
    normalized_price = normalize(price, 4, 70)   # 4만원~70만원 범위에서의 정규화 
    
    # 기사의 선호도에 따른 가중치 조합
    distance_weight = (driver['preference'] / 10) * 1.5
    price_weight = (1 - distance_weight + 0.1) * 0.5
    
    score = (distance_weight * (1 - normalized_distance)) + (price_weight * normalized_price)
    
    return score, distance_to_warehouse, distance_to_destination

# %%
import pandas as pd 

input_df = pd.read_excel('INPUT.xlsx')  # 기사 데이터
product_df = pd.read_excel('Dataset/PRODUCT.xlsx')  # 물류 데이터

# 모든 물류에 대해 기사와의 적합도 계산 및 추천
def recommend_top_logistics(driver, product_df, top_n):
    scores = []
    for _, logistics in product_df.iterrows():
        result = calculate_match_score(driver, logistics)
        if result:  # 튜플이 올바르게 반환된 경우 처리
            score, distance_to_warehouse, distance_to_destination = result
            scores.append((logistics['product_id'], score, distance_to_warehouse, distance_to_destination))
    
    # 상위 top_n개의 적합도 높은 물류 추천
    sorted_scores = sorted(scores, key=lambda x: x[1], reverse=True)[:top_n]
    
    # 추천 물류와 점수 및 거리 정보 리스트
    recommended_logistics = []
    for product_id, score, distance_to_warehouse, distance_to_destination in sorted_scores:
        logistics = product_df[product_df['product_id'] == product_id].iloc[0]
        recommended_logistics.append((logistics, score, distance_to_warehouse, distance_to_destination))
    
    return recommended_logistics

# 한 기사에 대해 추천 물류 찾기
driver = input_df.iloc[20]
recommended_logistics = recommend_top_logistics(driver, product_df, 1)

# 기사 정보 출력
print("기사 정보:")
print(driver)

# 1차 물류 추천 결과 및 상위 3개 물류의 score 출력
print("1차 물류 추천 결과:", recommended_logistics)
print("\n1차 물류 추천 결과:")
for logistics, score, distance_to_warehouse, distance_to_destination in recommended_logistics:
    print(f"물류 ID: {logistics['product_id']}, 점수: {score:.2f}, 창고 거리: {distance_to_warehouse:.2f} km, 목적지 거리: {distance_to_destination:.2f} km")
# Out:
# 기사 정보:
# user_id                                313
# max_weight                              14
# min_weight                               6
# departure           인천광역시 서구 정서진로 47 (오류동)
# departure_lat                    37.571656
# departure_long                  126.716622
# destination           전라남도 강진군 성전면 송계로 764
# destination_lat                  34.686319
# destination_long                 126.72048
# preference                               4
# Name: 20, dtype: object
# 1차 물류 추천 결과: [(user_id                                             64
# product_id                                        6330
# departure           인천광역시 중구 축항대로165번길 20, 물류센터 (항동7가)
# departure_lat                                37.455177
# departure_long                              126.616158
# name                                     건과제품, 빙과제품_29
# destination                      전라남도 해남군 해남읍 땅끝대로 141
# destination_lat                              34.556405
# destination_long                            126.583106
# weight                                               8
# deadline                              2024-11-23 02:00
# date                                        2024-11-19
# Name: 6329, dtype: object, 0.6793002943550231, 15.684824235289634, 19.141940105171344)]
#
# 1차 물류 추천 결과:
# 물류 ID: 6330, 점수: 0.68, 창고 거리: 15.68 km, 목적지 거리: 19.14 km

# %%
import pandas as pd

# 모든 기사에 대해 물류 추천 및 저장
def recommend_logistics_for_all_drivers(input_df, product_df, top_n, batch_size=1000):
    results = []  # 추천 결과 저장
    batch_count = 0  # 현재 배치 번호
    total_results = 0  # 총 결과 수
    
    for idx, driver in input_df.iterrows():
        # 각 기사에 대해 추천
        recommended_logistics = recommend_top_logistics(driver, product_df, top_n)
        
        # 추천 결과 처리
        for rank, (logistics, score, distance_to_warehouse, distance_to_destination) in enumerate(recommended_logistics, start=1):
            results.append({
                'user_id': driver['user_id'],                     # 기사 ID
                'departure': driver['departure'],                 # 기사 출발지
                'destination': driver['destination'],             # 기사 목적지
                'preference': driver['preference'],               # 기사 선호도
                'result_number': rank,                            # 추천 순위 (1, 2, 3)
                'product_id': logistics['product_id'],            # 물류 ID
                'prod_departure': logistics['departure'],         # 물류 출발지
                'prod_destination': logistics['destination'],     # 물류 목적지
                'score': score,                                   # 적합도 점수
                'distance_to_warehouse': distance_to_warehouse,   # 기사 출발지와 창고 간 거리
                'distance_to_destination': distance_to_destination  # 기사 목적지와 물류 도착지 간 거리
            })
            total_results += 1
        
        print(f"기사 {idx + 1}/{len(input_df)} (user_id: {driver['user_id']}) 추천 완료.")
        
        # 중간 결과 저장
        if total_results % batch_size == 0:
            batch_count += 1
            batch_file = f"First_Route_Part_{batch_count}.xlsx"
            pd.DataFrame(results).to_excel(batch_file, index=False)
            print(f"중간 결과 저장: {batch_file}")
            results = []  # 저장 후 리스트 초기화

    # 마지막 남은 결과 저장
    if results:
        batch_count += 1
        batch_file = f"First_Route_Part_{batch_count}.xlsx"
        pd.DataFrame(results).to_excel(batch_file, index=False)
        print(f"최종 결과 저장: {batch_file}")

# 추천 결과 계산
top_n = 3  # Top 3 추천
batch_size = 1000  # 중간 저장 기준
result_df = recommend_logistics_for_all_drivers(input_df, product_df, top_n, batch_size)
# Out:
# 기사 1/10000 (user_id: 412) 추천 완료.
# 기사 2/10000 (user_id: 399) 추천 완료.
# 기사 3/10000 (user_id: 426) 추천 완료.
# 기사 4/10000 (user_id: 432) 추천 완료.
# 기사 5/10000 (user_id: 297) 추천 완료.
# 기사 6/10000 (user_id: 419) 추천 완료.
# 기사 7/10000 (user_id: 304) 추천 완료.
# 기사 8/10000 (user_id: 272) 추천 완료.
# 기사 9/10000 (user_id: 290) 추천 완료.
# 기사 10/10000 (user_id: 180) 추천 완료.
# 기사 11/10000 (user_id: 192) 추천 완료.
# 기사 12/10000 (user_id: 453) 추천 완료.
# 기사 13/10000 (user_id: 183) 추천 완료.
# 기사 14/10000 (user_id: 372) 추천 완료.
# 기사 15/10000 (user_id: 305) 추천 완료.
# 기사 16/10000 (user_id: 285) 추천 완료.
# 기사 17/10000 (user_id: 242) 추천 완료.
# 기사 18/10000 (user_id: 409) 추천 완료.
# 기사 19/10000 (user_id: 395) 추천 완료.
# 기사 20/10000 (user_id: 303) 추천 완료.
# 기사 21/10000 (user_id: 313) 추천 완료.
# 기사 22/10000 (user_id: 458) 추천 완료.
# 기사 23/10000 (user_id: 198) 추천 완료.
# 기사 24/10000 (user_id: 223) 추천 완료.
# 기사 25/10000 (user_id: 218) 추천 완료.
# 기사 26/10000 (user_id: 258) 추천 완료.
# 기사 27/10000 (user_id: 286) 추천 완료.
# 기사 28/10000 (user_id: 173) 추천 완료.
# 기사 29/10000 (user_id: 188) 추천 완료.
# 기사 30/10000 (user_id: 377) 추천 완료.
# 기사 31/10000 (user_id: 180) 추천 완료.
# 기사 32/10000 (user_id: 436) 추천 완료.
# 기사 33/10000 (user_id: 351) 추천 완료.
# 기사 34/10000 (user_id: 382) 추천 완료.
# 기사 35/10000 (user_id: 234) 추천 완료.
# 기사 36/10000 (user_id: 175) 추천 완료.
# 기사 37/10000 (user_id: 428) 추천 완료.
# 기사 38/10000 (user_id: 289) 추천 완료.
# 기사 39/10000 (user_id: 199) 추천 완료.
# 기사 40/10000 (user_id: 339) 추천 완료.
# 기사 41/10000 (user_id: 426) 추천 완료.
# 기사 42/10000 (user_id: 377) 추천 완료.
# 기사 43/10000 (user_id: 259) 추천 완료.
# 기사 44/10000 (user_id: 207) 추천 완료.
# 기사 45/10000 (user_id: 454) 추천 완료.
# 기사 46/10000 (user_id: 414) 추천 완료.
# 기사 47/10000 (user_id: 379) 추천 완료.
# 기사 48/10000 (user_id: 218) 추천 완료.
# 기사 49/10000 (user_id: 163) 추천 완료.
# 기사 50/10000 (user_id: 240) 추천 완료.
# 기사 51/10000 (user_id: 240) 추천 완료.
# 기사 52/10000 (user_id: 381) 추천 완료.
# 기사 53/10000 (user_id: 408) 추천 완료.
# 기사 54/10000 (user_id: 268) 추천 완료.
# 기사 55/10000 (user_id: 455) 추천 완료.
# 기사 56/10000 (user_id: 458) 추천 완료.
# 기사 57/10000 (user_id: 167) 추천 완료.
# 기사 58/10000 (user_id: 443) 추천 완료.
# 기사 59/10000 (user_id: 233) 추천 완료.
# 기사 60/10000 (user_id: 303) 추천 완료.
# 기사 61/10000 (user_id: 377) 추천 완료.
# 기사 62/10000 (user_id: 371) 추천 완료.
# 기사 63/10000 (user_id: 386) 추천 완료.
# 기사 64/10000 (user_id: 195) 추천 완료.
# 기사 65/10000 (user_id: 293) 추천 완료.
# 기사 66/10000 (user_id: 238) 추천 완료.
# 기사 67/10000 (user_id: 421) 추천 완료.
# 기사 68/10000 (user_id: 295) 추천 완료.
# 기사 69/10000 (user_id: 409) 추천 완료.
# 기사 70/10000 (user_id: 193) 추천 완료.
# 기사 71/10000 (user_id: 331) 추천 완료.
# 기사 72/10000 (user_id: 210) 추천 완료.
# 기사 73/10000 (user_id: 187) 추천 완료.
# 기사 74/10000 (user_id: 391) 추천 완료.
# 기사 75/10000 (user_id: 401) 추천 완료.
# 기사 76/10000 (user_id: 404) 추천 완료.
# 기사 77/10000 (user_id: 168) 추천 완료.
# 기사 78/10000 (user_id: 338) 추천 완료.
# 기사 79/10000 (user_id: 431) 추천 완료.
# 기사 80/10000 (user_id: 439) 추천 완료.
# 기사 81/10000 (user_id: 384) 추천 완료.
# 기사 82/10000 (user_id: 170) 추천 완료.
# 기사 83/10000 (user_id: 218) 추천 완료.
# 기사 84/10000 (user_id: 268) 추천 완료.
# 기사 85/10000 (user_id: 304) 추천 완료.
# 기사 86/10000 (user_id: 293) 추천 완료.
# 기사 87/10000 (user_id: 299) 추천 완료.
# 기사 88/10000 (user_id: 389) 추천 완료.
# 기사 89/10000 (user_id: 197) 추천 완료.
# 기사 90/10000 (user_id: 417) 추천 완료.
# 기사 91/10000 (user_id: 181) 추천 완료.
# 기사 92/10000 (user_id: 446) 추천 완료.
# 기사 93/10000 (user_id: 247) 추천 완료.
# 기사 94/10000 (user_id: 339) 추천 완료.
# 기사 95/10000 (user_id: 447) 추천 완료.
# 기사 96/10000 (user_id: 435) 추천 완료.
# 기사 97/10000 (user_id: 289) 추천 완료.
# 기사 98/10000 (user_id: 355) 추천 완료.
# 기사 99/10000 (user_id: 373) 추천 완료.
# 기사 100/10000 (user_id: 185) 추천 완료.
# 기사 101/10000 (user_id: 459) 추천 완료.
# 기사 102/10000 (user_id: 173) 추천 완료.
# 기사 103/10000 (user_id: 307) 추천 완료.
# 기사 104/10000 (user_id: 165) 추천 완료.
# 기사 105/10000 (user_id: 234) 추천 완료.
# 기사 106/10000 (user_id: 425) 추천 완료.
# 기사 107/10000 (user_id: 393) 추천 완료.
# 기사 108/10000 (user_id: 406) 추천 완료.
# 기사 109/10000 (user_id: 382) 추천 완료.
# 기사 110/10000 (user_id: 252) 추천 완료.
# 기사 111/10000 (user_id: 442) 추천 완료.
# 기사 112/10000 (user_id: 329) 추천 완료.
# 기사 113/10000 (user_id: 346) 추천 완료.
# 기사 114/10000 (user_id: 251) 추천 완료.
# 기사 115/10000 (user_id: 397) 추천 완료.
# 기사 116/10000 (user_id: 347) 추천 완료.
# 기사 117/10000 (user_id: 419) 추천 완료.
# 기사 118/10000 (user_id: 305) 추천 완료.
# 기사 119/10000 (user_id: 362) 추천 완료.
# 기사 120/10000 (user_id: 288) 추천 완료.
# 기사 121/10000 (user_id: 458) 추천 완료.
# 기사 122/10000 (user_id: 395) 추천 완료.
# 기사 123/10000 (user_id: 217) 추천 완료.
# 기사 124/10000 (user_id: 215) 추천 완료.
# 기사 125/10000 (user_id: 408) 추천 완료.
# 기사 126/10000 (user_id: 307) 추천 완료.
# 기사 127/10000 (user_id: 401) 추천 완료.
# 기사 128/10000 (user_id: 296) 추천 완료.
# 기사 129/10000 (user_id: 386) 추천 완료.
# 기사 130/10000 (user_id: 351) 추천 완료.
# 기사 131/10000 (user_id: 446) 추천 완료.
# 기사 132/10000 (user_id: 457) 추천 완료.
# 기사 133/10000 (user_id: 275) 추천 완료.
# 기사 134/10000 (user_id: 325) 추천 완료.
# 기사 135/10000 (user_id: 381) 추천 완료.
# 기사 136/10000 (user_id: 333) 추천 완료.
# 기사 137/10000 (user_id: 296) 추천 완료.
# 기사 138/10000 (user_id: 276) 추천 완료.
# 기사 139/10000 (user_id: 188) 추천 완료.
# 기사 140/10000 (user_id: 245) 추천 완료.
# 기사 141/10000 (user_id: 423) 추천 완료.
# 기사 142/10000 (user_id: 398) 추천 완료.
# 기사 143/10000 (user_id: 254) 추천 완료.
# 기사 144/10000 (user_id: 216) 추천 완료.
# 기사 145/10000 (user_id: 299) 추천 완료.
# 기사 146/10000 (user_id: 430) 추천 완료.
# 기사 147/10000 (user_id: 314) 추천 완료.
# 기사 148/10000 (user_id: 259) 추천 완료.
# 기사 149/10000 (user_id: 161) 추천 완료.
# 기사 150/10000 (user_id: 192) 추천 완료.
# 기사 151/10000 (user_id: 292) 추천 완료.
# 기사 152/10000 (user_id: 391) 추천 완료.
# 기사 153/10000 (user_id: 282) 추천 완료.
# 기사 154/10000 (user_id: 188) 추천 완료.
# 기사 155/10000 (user_id: 267) 추천 완료.
# 기사 156/10000 (user_id: 433) 추천 완료.
# 기사 157/10000 (user_id: 335) 추천 완료.
# 기사 158/10000 (user_id: 306) 추천 완료.
# 기사 159/10000 (user_id: 374) 추천 완료.
# 기사 160/10000 (user_id: 320) 추천 완료.
# 기사 161/10000 (user_id: 349) 추천 완료.
# 기사 162/10000 (user_id: 240) 추천 완료.
# 기사 163/10000 (user_id: 223) 추천 완료.
# 기사 164/10000 (user_id: 243) 추천 완료.
# 기사 165/10000 (user_id: 404) 추천 완료.
# 기사 166/10000 (user_id: 161) 추천 완료.
# 기사 167/10000 (user_id: 456) 추천 완료.
# 기사 168/10000 (user_id: 274) 추천 완료.
# 기사 169/10000 (user_id: 254) 추천 완료.
# 기사 170/10000 (user_id: 444) 추천 완료.
# 기사 171/10000 (user_id: 228) 추천 완료.
# 기사 172/10000 (user_id: 287) 추천 완료.
# 기사 173/10000 (user_id: 191) 추천 완료.
# 기사 174/10000 (user_id: 355) 추천 완료.
# 기사 175/10000 (user_id: 280) 추천 완료.
# 기사 176/10000 (user_id: 174) 추천 완료.
# 기사 177/10000 (user_id: 216) 추천 완료.
# 기사 178/10000 (user_id: 177) 추천 완료.
# 기사 179/10000 (user_id: 447) 추천 완료.
# 기사 180/10000 (user_id: 445) 추천 완료.
# 기사 181/10000 (user_id: 347) 추천 완료.
# 기사 182/10000 (user_id: 304) 추천 완료.
# 기사 183/10000 (user_id: 269) 추천 완료.
# 기사 184/10000 (user_id: 382) 추천 완료.
# 기사 185/10000 (user_id: 240) 추천 완료.
# 기사 186/10000 (user_id: 209) 추천 완료.
# 기사 187/10000 (user_id: 266) 추천 완료.
# 기사 188/10000 (user_id: 246) 추천 완료.
# 기사 189/10000 (user_id: 233) 추천 완료.
# 기사 190/10000 (user_id: 189) 추천 완료.
# 기사 191/10000 (user_id: 247) 추천 완료.
# 기사 192/10000 (user_id: 291) 추천 완료.
# 기사 193/10000 (user_id: 258) 추천 완료.
# 기사 194/10000 (user_id: 321) 추천 완료.
# 기사 195/10000 (user_id: 363) 추천 완료.
# 기사 196/10000 (user_id: 258) 추천 완료.
# 기사 197/10000 (user_id: 285) 추천 완료.
# 기사 198/10000 (user_id: 293) 추천 완료.
# 기사 199/10000 (user_id: 404) 추천 완료.
# 기사 200/10000 (user_id: 422) 추천 완료.
# 기사 201/10000 (user_id: 451) 추천 완료.
# 기사 202/10000 (user_id: 212) 추천 완료.
# 기사 203/10000 (user_id: 238) 추천 완료.
# 기사 204/10000 (user_id: 457) 추천 완료.
# 기사 205/10000 (user_id: 344) 추천 완료.
# 기사 206/10000 (user_id: 387) 추천 완료.
# 기사 207/10000 (user_id: 395) 추천 완료.
# 기사 208/10000 (user_id: 318) 추천 완료.
# 기사 209/10000 (user_id: 399) 추천 완료.
# 기사 210/10000 (user_id: 208) 추천 완료.
# 기사 211/10000 (user_id: 249) 추천 완료.
# 기사 212/10000 (user_id: 284) 추천 완료.
# 기사 213/10000 (user_id: 395) 추천 완료.
# 기사 214/10000 (user_id: 164) 추천 완료.
# 기사 215/10000 (user_id: 419) 추천 완료.
# 기사 216/10000 (user_id: 437) 추천 완료.
# 기사 217/10000 (user_id: 229) 추천 완료.
# 기사 218/10000 (user_id: 295) 추천 완료.
# 기사 219/10000 (user_id: 338) 추천 완료.
# 기사 220/10000 (user_id: 179) 추천 완료.
# 기사 221/10000 (user_id: 285) 추천 완료.
# 기사 222/10000 (user_id: 212) 추천 완료.
# 기사 223/10000 (user_id: 451) 추천 완료.
# 기사 224/10000 (user_id: 222) 추천 완료.
# 기사 225/10000 (user_id: 352) 추천 완료.
# 기사 226/10000 (user_id: 360) 추천 완료.
# 기사 227/10000 (user_id: 332) 추천 완료.
# 기사 228/10000 (user_id: 441) 추천 완료.
# 기사 229/10000 (user_id: 285) 추천 완료.
# 기사 230/10000 (user_id: 214) 추천 완료.
# 기사 231/10000 (user_id: 444) 추천 완료.
# 기사 232/10000 (user_id: 229) 추천 완료.
# 기사 233/10000 (user_id: 434) 추천 완료.
# 기사 234/10000 (user_id: 452) 추천 완료.
# 기사 235/10000 (user_id: 351) 추천 완료.
# 기사 236/10000 (user_id: 402) 추천 완료.
# 기사 237/10000 (user_id: 338) 추천 완료.
# 기사 238/10000 (user_id: 306) 추천 완료.
# 기사 239/10000 (user_id: 168) 추천 완료.
# 기사 240/10000 (user_id: 260) 추천 완료.
# 기사 241/10000 (user_id: 238) 추천 완료.
# 기사 242/10000 (user_id: 414) 추천 완료.
# 기사 243/10000 (user_id: 171) 추천 완료.
# 기사 244/10000 (user_id: 343) 추천 완료.
# 기사 245/10000 (user_id: 374) 추천 완료.
# 기사 246/10000 (user_id: 423) 추천 완료.
# 기사 247/10000 (user_id: 258) 추천 완료.
# 기사 248/10000 (user_id: 389) 추천 완료.
# 기사 249/10000 (user_id: 431) 추천 완료.
# 기사 250/10000 (user_id: 169) 추천 완료.
# 기사 251/10000 (user_id: 445) 추천 완료.
# 기사 252/10000 (user_id: 399) 추천 완료.
# 기사 253/10000 (user_id: 400) 추천 완료.
# 기사 254/10000 (user_id: 191) 추천 완료.
# 기사 255/10000 (user_id: 331) 추천 완료.
# 기사 256/10000 (user_id: 232) 추천 완료.
# 기사 257/10000 (user_id: 414) 추천 완료.
# 기사 258/10000 (user_id: 203) 추천 완료.
# 기사 259/10000 (user_id: 386) 추천 완료.
# 기사 260/10000 (user_id: 324) 추천 완료.
# 기사 261/10000 (user_id: 324) 추천 완료.
# 기사 262/10000 (user_id: 330) 추천 완료.
# 기사 263/10000 (user_id: 411) 추천 완료.
# 기사 264/10000 (user_id: 230) 추천 완료.
# 기사 265/10000 (user_id: 332) 추천 완료.
# 기사 266/10000 (user_id: 422) 추천 완료.
# 기사 267/10000 (user_id: 321) 추천 완료.
# 기사 268/10000 (user_id: 342) 추천 완료.
# 기사 269/10000 (user_id: 392) 추천 완료.
# 기사 270/10000 (user_id: 413) 추천 완료.
# 기사 271/10000 (user_id: 303) 추천 완료.
# 기사 272/10000 (user_id: 421) 추천 완료.
# 기사 273/10000 (user_id: 189) 추천 완료.
# 기사 274/10000 (user_id: 432) 추천 완료.
# 기사 275/10000 (user_id: 249) 추천 완료.
# 기사 276/10000 (user_id: 263) 추천 완료.
# 기사 277/10000 (user_id: 199) 추천 완료.
# 기사 278/10000 (user_id: 358) 추천 완료.
# 기사 279/10000 (user_id: 196) 추천 완료.
# 기사 280/10000 (user_id: 247) 추천 완료.
# 기사 281/10000 (user_id: 408) 추천 완료.
# 기사 282/10000 (user_id: 450) 추천 완료.
# 기사 283/10000 (user_id: 193) 추천 완료.
# 기사 284/10000 (user_id: 259) 추천 완료.
# 기사 285/10000 (user_id: 260) 추천 완료.
# 기사 286/10000 (user_id: 284) 추천 완료.
# 기사 287/10000 (user_id: 222) 추천 완료.
# 기사 288/10000 (user_id: 313) 추천 완료.
# 기사 289/10000 (user_id: 169) 추천 완료.
# 기사 290/10000 (user_id: 230) 추천 완료.
# 기사 291/10000 (user_id: 296) 추천 완료.
# 기사 292/10000 (user_id: 338) 추천 완료.
# 기사 293/10000 (user_id: 349) 추천 완료.
# 기사 294/10000 (user_id: 301) 추천 완료.
# 기사 295/10000 (user_id: 238) 추천 완료.
# 기사 296/10000 (user_id: 256) 추천 완료.
# 기사 297/10000 (user_id: 213) 추천 완료.
# 기사 298/10000 (user_id: 399) 추천 완료.
# 기사 299/10000 (user_id: 368) 추천 완료.
# 기사 300/10000 (user_id: 435) 추천 완료.
# 기사 301/10000 (user_id: 241) 추천 완료.
# 기사 302/10000 (user_id: 244) 추천 완료.
# 기사 303/10000 (user_id: 195) 추천 완료.
# 기사 304/10000 (user_id: 383) 추천 완료.
# 기사 305/10000 (user_id: 267) 추천 완료.
# 기사 306/10000 (user_id: 379) 추천 완료.
# 기사 307/10000 (user_id: 434) 추천 완료.
# 기사 367/10000 (user_id: 424) 추천 완료.
# 기사 368/10000 (user_id: 297) 추천 완료.
# 기사 369/10000 (user_id: 357) 추천 완료.
# 기사 370/10000 (user_id: 292) 추천 완료.
# 기사 371/10000 (user_id: 359) 추천 완료.
# 기사 372/10000 (user_id: 187) 추천 완료.
# 기사 373/10000 (user_id: 185) 추천 완료.
# 기사 374/10000 (user_id: 323) 추천 완료.
# 기사 375/10000 (user_id: 285) 추천 완료.
# 기사 376/10000 (user_id: 251) 추천 완료.
# 기사 377/10000 (user_id: 413) 추천 완료.
# 기사 378/10000 (user_id: 202) 추천 완료.
# 기사 379/10000 (user_id: 387) 추천 완료.
# 기사 380/10000 (user_id: 242) 추천 완료.
# 기사 381/10000 (user_id: 365) 추천 완료.
# 기사 382/10000 (user_id: 382) 추천 완료.
# 기사 383/10000 (user_id: 194) 추천 완료.
# 기사 384/10000 (user_id: 432) 추천 완료.
# 기사 385/10000 (user_id: 226) 추천 완료.
# 기사 386/10000 (user_id: 389) 추천 완료.
# 기사 387/10000 (user_id: 249) 추천 완료.
# 기사 388/10000 (user_id: 258) 추천 완료.
# 기사 389/10000 (user_id: 347) 추천 완료.
# 기사 390/10000 (user_id: 305) 추천 완료.
# 기사 391/10000 (user_id: 311) 추천 완료.
# 기사 392/10000 (user_id: 412) 추천 완료.
# 기사 393/10000 (user_id: 199) 추천 완료.
# 기사 394/10000 (user_id: 430) 추천 완료.
# 기사 395/10000 (user_id: 366) 추천 완료.
# 기사 396/10000 (user_id: 278) 추천 완료.
# 기사 397/10000 (user_id: 171) 추천 완료.
# 기사 398/10000 (user_id: 174) 추천 완료.
# 기사 399/10000 (user_id: 285) 추천 완료.
# 기사 400/10000 (user_id: 354) 추천 완료.
# 기사 401/10000 (user_id: 307) 추천 완료.
# 기사 402/10000 (user_id: 315) 추천 완료.
# 기사 403/10000 (user_id: 396) 추천 완료.
# 기사 404/10000 (user_id: 309) 추천 완료.
# 기사 405/10000 (user_id: 421) 추천 완료.
# 기사 406/10000 (user_id: 357) 추천 완료.
# 기사 407/10000 (user_id: 442) 추천 완료.
# 기사 408/10000 (user_id: 335) 추천 완료.
# 기사 409/10000 (user_id: 218) 추천 완료.
# 기사 410/10000 (user_id: 302) 추천 완료.
# 중간 결과 저장: First_Route_Part_1.xlsx
# 기사 411/10000 (user_id: 247) 추천 완료.
# 기사 412/10000 (user_id: 416) 추천 완료.
# 기사 413/10000 (user_id: 435) 추천 완료.
# 기사 414/10000 (user_id: 176) 추천 완료.
# 기사 415/10000 (user_id: 452) 추천 완료.
# 기사 416/10000 (user_id: 421) 추천 완료.
# 기사 417/10000 (user_id: 305) 추천 완료.
# 기사 418/10000 (user_id: 420) 추천 완료.
# 기사 419/10000 (user_id: 213) 추천 완료.
# 기사 420/10000 (user_id: 241) 추천 완료.
# 기사 421/10000 (user_id: 337) 추천 완료.
# 기사 422/10000 (user_id: 302) 추천 완료.
# 기사 423/10000 (user_id: 460) 추천 완료.
# 기사 424/10000 (user_id: 171) 추천 완료.
# 기사 484/10000 (user_id: 297) 추천 완료.
# 기사 485/10000 (user_id: 440) 추천 완료.
# 기사 486/10000 (user_id: 206) 추천 완료.
# 기사 487/10000 (user_id: 407) 추천 완료.
# 기사 488/10000 (user_id: 247) 추천 완료.
# 기사 489/10000 (user_id: 247) 추천 완료.
# 기사 490/10000 (user_id: 319) 추천 완료.
# 기사 491/10000 (user_id: 280) 추천 완료.
# 기사 492/10000 (user_id: 434) 추천 완료.
# 기사 493/10000 (user_id: 324) 추천 완료.
# 기사 494/10000 (user_id: 195) 추천 완료.
# 기사 495/10000 (user_id: 232) 추천 완료.
# 기사 496/10000 (user_id: 357) 추천 완료.
# 기사 497/10000 (user_id: 282) 추천 완료.
# 기사 498/10000 (user_id: 348) 추천 완료.
# 기사 499/10000 (user_id: 198) 추천 완료.
# 기사 500/10000 (user_id: 441) 추천 완료.
# 기사 501/10000 (user_id: 448) 추천 완료.
# 기사 502/10000 (user_id: 210) 추천 완료.
# 기사 503/10000 (user_id: 256) 추천 완료.
# 기사 504/10000 (user_id: 365) 추천 완료.
# 기사 505/10000 (user_id: 393) 추천 완료.
# 기사 506/10000 (user_id: 355) 추천 완료.
# 기사 507/10000 (user_id: 234) 추천 완료.
# 기사 508/10000 (user_id: 378) 추천 완료.
# 기사 509/10000 (user_id: 303) 추천 완료.
# 기사 510/10000 (user_id: 194) 추천 완료.
# 기사 511/10000 (user_id: 225) 추천 완료.
# 기사 512/10000 (user_id: 217) 추천 완료.
# 기사 513/10000 (user_id: 298) 추천 완료.
# 기사 514/10000 (user_id: 450) 추천 완료.
# 기사 515/10000 (user_id: 311) 추천 완료.
# 기사 516/10000 (user_id: 446) 추천 완료.
# 기사 517/10000 (user_id: 184) 추천 완료.
# 기사 518/10000 (user_id: 177) 추천 완료.
# 기사 519/10000 (user_id: 241) 추천 완료.
# 기사 520/10000 (user_id: 200) 추천 완료.
# 기사 521/10000 (user_id: 343) 추천 완료.
# 기사 522/10000 (user_id: 165) 추천 완료.
# 기사 523/10000 (user_id: 185) 추천 완료.
# 기사 524/10000 (user_id: 194) 추천 완료.
# 기사 525/10000 (user_id: 366) 추천 완료.
# 기사 526/10000 (user_id: 352) 추천 완료.
# 기사 527/10000 (user_id: 207) 추천 완료.
# 기사 528/10000 (user_id: 383) 추천 완료.
# 기사 529/10000 (user_id: 398) 추천 완료.
# 기사 530/10000 (user_id: 204) 추천 완료.
# 기사 531/10000 (user_id: 254) 추천 완료.
# 기사 532/10000 (user_id: 222) 추천 완료.
# 기사 533/10000 (user_id: 204) 추천 완료.
# 기사 534/10000 (user_id: 406) 추천 완료.
# 기사 535/10000 (user_id: 460) 추천 완료.
# 기사 536/10000 (user_id: 434) 추천 완료.
# 기사 537/10000 (user_id: 168) 추천 완료.
# 기사 538/10000 (user_id: 177) 추천 완료.
# 기사 539/10000 (user_id: 249) 추천 완료.
# 기사 540/10000 (user_id: 310) 추천 완료.
# 기사 541/10000 (user_id: 396) 추천 완료.
# 기사 542/10000 (user_id: 249) 추천 완료.
# 기사 543/10000 (user_id: 169) 추천 완료.
# 기사 544/10000 (user_id: 334) 추천 완료.
# 기사 545/10000 (user_id: 323) 추천 완료.
# 기사 546/10000 (user_id: 438) 추천 완료.
# 기사 547/10000 (user_id: 205) 추천 완료.
# 기사 548/10000 (user_id: 374) 추천 완료.
# 기사 549/10000 (user_id: 295) 추천 완료.
# 기사 550/10000 (user_id: 249) 추천 완료.
# 기사 551/10000 (user_id: 313) 추천 완료.
# 기사 552/10000 (user_id: 224) 추천 완료.
# 기사 553/10000 (user_id: 177) 추천 완료.
# 기사 554/10000 (user_id: 376) 추천 완료.
# 기사 555/10000 (user_id: 375) 추천 완료.
# 기사 556/10000 (user_id: 184) 추천 완료.
# 기사 557/10000 (user_id: 290) 추천 완료.
# 기사 558/10000 (user_id: 287) 추천 완료.
# 기사 559/10000 (user_id: 211) 추천 완료.
# 기사 560/10000 (user_id: 415) 추천 완료.
# 기사 561/10000 (user_id: 328) 추천 완료.
# 기사 562/10000 (user_id: 275) 추천 완료.
# 기사 563/10000 (user_id: 224) 추천 완료.
# 기사 564/10000 (user_id: 341) 추천 완료.
# 기사 565/10000 (user_id: 381) 추천 완료.
# 기사 566/10000 (user_id: 210) 추천 완료.
# 기사 567/10000 (user_id: 239) 추천 완료.
# 기사 568/10000 (user_id: 230) 추천 완료.
# 기사 569/10000 (user_id: 253) 추천 완료.
# 기사 570/10000 (user_id: 255) 추천 완료.
# 기사 571/10000 (user_id: 271) 추천 완료.
# 기사 572/10000 (user_id: 236) 추천 완료.
# 기사 573/10000 (user_id: 312) 추천 완료.
# 기사 574/10000 (user_id: 255) 추천 완료.
# 기사 575/10000 (user_id: 221) 추천 완료.
# 기사 576/10000 (user_id: 329) 추천 완료.
# 기사 577/10000 (user_id: 362) 추천 완료.
# 기사 578/10000 (user_id: 197) 추천 완료.
# 기사 579/10000 (user_id: 169) 추천 완료.
# 기사 580/10000 (user_id: 332) 추천 완료.
# 기사 581/10000 (user_id: 241) 추천 완료.
# 기사 582/10000 (user_id: 355) 추천 완료.
# 기사 583/10000 (user_id: 296) 추천 완료.
# 기사 584/10000 (user_id: 277) 추천 완료.
# 기사 585/10000 (user_id: 431) 추천 완료.
# 기사 586/10000 (user_id: 175) 추천 완료.
# 기사 587/10000 (user_id: 332) 추천 완료.
# 기사 588/10000 (user_id: 254) 추천 완료.
# 기사 589/10000 (user_id: 397) 추천 완료.
# 기사 590/10000 (user_id: 369) 추천 완료.
# 기사 591/10000 (user_id: 229) 추천 완료.
# 기사 592/10000 (user_id: 354) 추천 완료.
# 기사 593/10000 (user_id: 208) 추천 완료.
# 기사 594/10000 (user_id: 373) 추천 완료.
# 기사 595/10000 (user_id: 224) 추천 완료.
# 기사 596/10000 (user_id: 339) 추천 완료.
# 기사 597/10000 (user_id: 286) 추천 완료.
# 기사 598/10000 (user_id: 183) 추천 완료.
# 기사 599/10000 (user_id: 450) 추천 완료.
# 기사 600/10000 (user_id: 263) 추천 완료.
# 기사 601/10000 (user_id: 337) 추천 완료.
# 기사 602/10000 (user_id: 235) 추천 완료.
# 기사 603/10000 (user_id: 278) 추천 완료.
# 기사 604/10000 (user_id: 257) 추천 완료.
# 기사 605/10000 (user_id: 216) 추천 완료.
# 기사 606/10000 (user_id: 201) 추천 완료.
# 기사 607/10000 (user_id: 406) 추천 완료.
# 기사 608/10000 (user_id: 177) 추천 완료.
# 기사 609/10000 (user_id: 263) 추천 완료.
# 기사 610/10000 (user_id: 221) 추천 완료.
# 기사 611/10000 (user_id: 233) 추천 완료.
# 기사 612/10000 (user_id: 439) 추천 완료.
# 기사 613/10000 (user_id: 421) 추천 완료.
# 기사 614/10000 (user_id: 440) 추천 완료.
# 기사 615/10000 (user_id: 286) 추천 완료.
# 기사 616/10000 (user_id: 314) 추천 완료.
# 기사 617/10000 (user_id: 434) 추천 완료.
# 기사 618/10000 (user_id: 337) 추천 완료.
# 기사 619/10000 (user_id: 188) 추천 완료.
# 기사 620/10000 (user_id: 229) 추천 완료.
# 기사 621/10000 (user_id: 241) 추천 완료.
# 기사 622/10000 (user_id: 325) 추천 완료.
# 기사 623/10000 (user_id: 244) 추천 완료.
# 기사 624/10000 (user_id: 223) 추천 완료.
# 기사 625/10000 (user_id: 239) 추천 완료.
# 기사 626/10000 (user_id: 215) 추천 완료.
# 기사 627/10000 (user_id: 459) 추천 완료.
# 기사 628/10000 (user_id: 437) 추천 완료.
# 기사 629/10000 (user_id: 396) 추천 완료.
# 기사 630/10000 (user_id: 425) 추천 완료.
# 기사 631/10000 (user_id: 272) 추천 완료.
# 기사 632/10000 (user_id: 251) 추천 완료.
# 기사 633/10000 (user_id: 187) 추천 완료.
# 기사 634/10000 (user_id: 164) 추천 완료.
# 기사 635/10000 (user_id: 407) 추천 완료.
# 기사 636/10000 (user_id: 389) 추천 완료.
# 기사 637/10000 (user_id: 189) 추천 완료.
# 기사 638/10000 (user_id: 189) 추천 완료.
# 기사 639/10000 (user_id: 161) 추천 완료.
# 기사 640/10000 (user_id: 293) 추천 완료.
# 기사 641/10000 (user_id: 427) 추천 완료.
# 기사 642/10000 (user_id: 379) 추천 완료.
# 기사 643/10000 (user_id: 211) 추천 완료.
# 기사 644/10000 (user_id: 393) 추천 완료.
# 기사 645/10000 (user_id: 257) 추천 완료.
# 기사 646/10000 (user_id: 256) 추천 완료.
# 기사 647/10000 (user_id: 285) 추천 완료.
# 기사 648/10000 (user_id: 346) 추천 완료.
# 기사 649/10000 (user_id: 301) 추천 완료.
# 기사 650/10000 (user_id: 221) 추천 완료.
# 기사 651/10000 (user_id: 207) 추천 완료.
# 기사 652/10000 (user_id: 432) 추천 완료.
# 기사 653/10000 (user_id: 322) 추천 완료.
# 기사 654/10000 (user_id: 191) 추천 완료.
# 기사 655/10000 (user_id: 367) 추천 완료.
# 기사 656/10000 (user_id: 317) 추천 완료.
# 기사 657/10000 (user_id: 295) 추천 완료.
# 기사 658/10000 (user_id: 176) 추천 완료.
# 기사 659/10000 (user_id: 224) 추천 완료.
# 기사 660/10000 (user_id: 414) 추천 완료.
# 기사 720/10000 (user_id: 447) 추천 완료.
# 기사 721/10000 (user_id: 219) 추천 완료.
# 기사 722/10000 (user_id: 303) 추천 완료.
# 기사 723/10000 (user_id: 450) 추천 완료.
# 기사 724/10000 (user_id: 316) 추천 완료.
# 기사 725/10000 (user_id: 249) 추천 완료.
# 기사 726/10000 (user_id: 431) 추천 완료.
# 기사 727/10000 (user_id: 420) 추천 완료.
# 기사 728/10000 (user_id: 193) 추천 완료.
# 기사 729/10000 (user_id: 277) 추천 완료.
# 기사 730/10000 (user_id: 406) 추천 완료.
# 기사 731/10000 (user_id: 318) 추천 완료.
# 기사 732/10000 (user_id: 167) 추천 완료.
# 기사 733/10000 (user_id: 425) 추천 완료.
# 기사 734/10000 (user_id: 431) 추천 완료.
# 기사 735/10000 (user_id: 196) 추천 완료.
# 기사 736/10000 (user_id: 342) 추천 완료.
# 기사 737/10000 (user_id: 426) 추천 완료.
# 기사 738/10000 (user_id: 345) 추천 완료.
# 기사 739/10000 (user_id: 181) 추천 완료.
# 기사 740/10000 (user_id: 296) 추천 완료.
# 기사 741/10000 (user_id: 221) 추천 완료.
# 기사 742/10000 (user_id: 434) 추천 완료.
# 기사 743/10000 (user_id: 185) 추천 완료.
# 기사 744/10000 (user_id: 305) 추천 완료.
# 기사 745/10000 (user_id: 219) 추천 완료.
# 기사 746/10000 (user_id: 382) 추천 완료.
# 기사 747/10000 (user_id: 414) 추천 완료.
# 기사 748/10000 (user_id: 409) 추천 완료.
# 기사 749/10000 (user_id: 440) 추천 완료.
# 기사 750/10000 (user_id: 201) 추천 완료.
# 기사 751/10000 (user_id: 261) 추천 완료.
# 기사 752/10000 (user_id: 228) 추천 완료.
# 기사 753/10000 (user_id: 165) 추천 완료.
# 기사 754/10000 (user_id: 327) 추천 완료.
# 기사 755/10000 (user_id: 418) 추천 완료.
# 기사 756/10000 (user_id: 450) 추천 완료.
# 기사 757/10000 (user_id: 342) 추천 완료.
# 기사 758/10000 (user_id: 171) 추천 완료.
# 기사 759/10000 (user_id: 326) 추천 완료.
# 기사 760/10000 (user_id: 336) 추천 완료.
# 기사 761/10000 (user_id: 291) 추천 완료.
# 기사 762/10000 (user_id: 230) 추천 완료.
# 기사 763/10000 (user_id: 220) 추천 완료.
# 기사 764/10000 (user_id: 397) 추천 완료.
# 기사 765/10000 (user_id: 448) 추천 완료.
# 기사 766/10000 (user_id: 446) 추천 완료.
# 기사 767/10000 (user_id: 334) 추천 완료.
# 기사 768/10000 (user_id: 177) 추천 완료.
# 기사 769/10000 (user_id: 324) 추천 완료.
# 기사 770/10000 (user_id: 452) 추천 완료.
# 기사 771/10000 (user_id: 383) 추천 완료.
# 기사 772/10000 (user_id: 419) 추천 완료.
# 기사 773/10000 (user_id: 195) 추천 완료.
# 기사 774/10000 (user_id: 206) 추천 완료.
# 기사 775/10000 (user_id: 416) 추천 완료.
# 기사 776/10000 (user_id: 313) 추천 완료.
# 기사 777/10000 (user_id: 390) 추천 완료.
# 기사 778/10000 (user_id: 406) 추천 완료.
# 기사 779/10000 (user_id: 212) 추천 완료.
# 기사 780/10000 (user_id: 195) 추천 완료.
# 기사 781/10000 (user_id: 383) 추천 완료.
# 기사 782/10000 (user_id: 349) 추천 완료.
# 기사 783/10000 (user_id: 172) 추천 완료.
# 기사 784/10000 (user_id: 388) 추천 완료.
# 기사 785/10000 (user_id: 339) 추천 완료.
# 기사 786/10000 (user_id: 204) 추천 완료.
# 기사 787/10000 (user_id: 448) 추천 완료.
# 기사 788/10000 (user_id: 194) 추천 완료.
# 기사 789/10000 (user_id: 309) 추천 완료.
# 기사 790/10000 (user_id: 395) 추천 완료.
# 기사 791/10000 (user_id: 162) 추천 완료.
# 기사 792/10000 (user_id: 459) 추천 완료.
# 기사 793/10000 (user_id: 179) 추천 완료.
# 기사 794/10000 (user_id: 308) 추천 완료.
# 기사 795/10000 (user_id: 310) 추천 완료.
# 기사 796/10000 (user_id: 362) 추천 완료.
# 기사 797/10000 (user_id: 276) 추천 완료.
# 기사 798/10000 (user_id: 372) 추천 완료.
# 기사 799/10000 (user_id: 205) 추천 완료.
# 기사 800/10000 (user_id: 310) 추천 완료.
# 기사 801/10000 (user_id: 313) 추천 완료.
# 기사 802/10000 (user_id: 181) 추천 완료.
# 기사 803/10000 (user_id: 232) 추천 완료.
# 기사 804/10000 (user_id: 271) 추천 완료.
# 기사 805/10000 (user_id: 376) 추천 완료.
# 기사 806/10000 (user_id: 410) 추천 완료.
# 기사 807/10000 (user_id: 367) 추천 완료.
# 기사 808/10000 (user_id: 450) 추천 완료.
# 기사 809/10000 (user_id: 424) 추천 완료.
# 기사 810/10000 (user_id: 458) 추천 완료.
# 기사 811/10000 (user_id: 361) 추천 완료.
# 기사 812/10000 (user_id: 372) 추천 완료.
# 기사 813/10000 (user_id: 406) 추천 완료.
# 기사 814/10000 (user_id: 343) 추천 완료.
# 기사 815/10000 (user_id: 169) 추천 완료.
# 기사 816/10000 (user_id: 378) 추천 완료.
# 기사 817/10000 (user_id: 337) 추천 완료.
# 기사 818/10000 (user_id: 315) 추천 완료.
# 기사 819/10000 (user_id: 202) 추천 완료.
# 기사 820/10000 (user_id: 321) 추천 완료.
# 기사 821/10000 (user_id: 433) 추천 완료.
# 기사 822/10000 (user_id: 324) 추천 완료.
# 기사 823/10000 (user_id: 181) 추천 완료.
# 기사 824/10000 (user_id: 353) 추천 완료.
# 기사 825/10000 (user_id: 205) 추천 완료.
# 기사 826/10000 (user_id: 423) 추천 완료.
# 기사 827/10000 (user_id: 289) 추천 완료.
# 기사 828/10000 (user_id: 213) 추천 완료.
# 기사 829/10000 (user_id: 289) 추천 완료.
# 기사 830/10000 (user_id: 234) 추천 완료.
# 기사 831/10000 (user_id: 434) 추천 완료.
# 기사 832/10000 (user_id: 222) 추천 완료.
# 기사 833/10000 (user_id: 211) 추천 완료.
# 기사 834/10000 (user_id: 302) 추천 완료.
# 기사 835/10000 (user_id: 264) 추천 완료.
# 기사 836/10000 (user_id: 192) 추천 완료.
# 기사 837/10000 (user_id: 371) 추천 완료.
# 기사 838/10000 (user_id: 198) 추천 완료.
# 기사 897/10000 (user_id: 322) 추천 완료.
# 기사 898/10000 (user_id: 290) 추천 완료.
# 기사 899/10000 (user_id: 357) 추천 완료.
# 기사 900/10000 (user_id: 428) 추천 완료.
# 기사 901/10000 (user_id: 292) 추천 완료.
# 기사 902/10000 (user_id: 325) 추천 완료.
# 기사 903/10000 (user_id: 190) 추천 완료.
# 기사 904/10000 (user_id: 166) 추천 완료.
# 기사 905/10000 (user_id: 326) 추천 완료.
# 기사 906/10000 (user_id: 365) 추천 완료.
# 기사 907/10000 (user_id: 440) 추천 완료.
# 기사 908/10000 (user_id: 418) 추천 완료.
# 기사 909/10000 (user_id: 298) 추천 완료.
# 기사 910/10000 (user_id: 357) 추천 완료.
# 기사 911/10000 (user_id: 444) 추천 완료.
# 기사 912/10000 (user_id: 389) 추천 완료.
# 기사 913/10000 (user_id: 393) 추천 완료.
# 기사 914/10000 (user_id: 401) 추천 완료.
# 기사 915/10000 (user_id: 421) 추천 완료.
# 기사 916/10000 (user_id: 422) 추천 완료.
# 기사 917/10000 (user_id: 259) 추천 완료.
# 기사 918/10000 (user_id: 423) 추천 완료.
# 기사 919/10000 (user_id: 249) 추천 완료.
# 기사 920/10000 (user_id: 195) 추천 완료.
# 기사 921/10000 (user_id: 275) 추천 완료.
# 기사 922/10000 (user_id: 297) 추천 완료.
# 기사 923/10000 (user_id: 366) 추천 완료.
# 기사 924/10000 (user_id: 215) 추천 완료.
# 기사 925/10000 (user_id: 166) 추천 완료.
# 기사 926/10000 (user_id: 339) 추천 완료.
# 기사 927/10000 (user_id: 443) 추천 완료.
# 기사 928/10000 (user_id: 249) 추천 완료.
# 기사 929/10000 (user_id: 302) 추천 완료.
# 기사 930/10000 (user_id: 396) 추천 완료.
# 기사 931/10000 (user_id: 192) 추천 완료.
# 기사 932/10000 (user_id: 408) 추천 완료.
# 기사 933/10000 (user_id: 274) 추천 완료.
# 기사 934/10000 (user_id: 261) 추천 완료.
# 기사 935/10000 (user_id: 174) 추천 완료.
# 기사 936/10000 (user_id: 322) 추천 완료.
# 기사 937/10000 (user_id: 380) 추천 완료.
# 기사 938/10000 (user_id: 179) 추천 완료.
# 기사 939/10000 (user_id: 296) 추천 완료.
# 기사 940/10000 (user_id: 381) 추천 완료.
# 기사 941/10000 (user_id: 352) 추천 완료.
# 기사 942/10000 (user_id: 366) 추천 완료.
# 기사 943/10000 (user_id: 241) 추천 완료.
# 기사 944/10000 (user_id: 225) 추천 완료.
# 기사 945/10000 (user_id: 377) 추천 완료.
# 기사 946/10000 (user_id: 433) 추천 완료.
# 기사 947/10000 (user_id: 431) 추천 완료.
# 기사 948/10000 (user_id: 222) 추천 완료.
# 기사 949/10000 (user_id: 398) 추천 완료.
# 기사 950/10000 (user_id: 441) 추천 완료.
# 기사 951/10000 (user_id: 372) 추천 완료.
# 기사 952/10000 (user_id: 307) 추천 완료.
# 기사 953/10000 (user_id: 336) 추천 완료.
# 기사 954/10000 (user_id: 400) 추천 완료.
# 기사 955/10000 (user_id: 306) 추천 완료.
# 기사 956/10000 (user_id: 325) 추천 완료.
# 기사 957/10000 (user_id: 339) 추천 완료.
# 기사 958/10000 (user_id: 358) 추천 완료.
# 기사 959/10000 (user_id: 454) 추천 완료.
# 기사 960/10000 (user_id: 169) 추천 완료.
# 기사 961/10000 (user_id: 345) 추천 완료.
# 기사 962/10000 (user_id: 389) 추천 완료.
# 기사 963/10000 (user_id: 268) 추천 완료.
# 기사 964/10000 (user_id: 427) 추천 완료.
# 기사 965/10000 (user_id: 225) 추천 완료.
# 기사 966/10000 (user_id: 366) 추천 완료.
# 기사 967/10000 (user_id: 272) 추천 완료.
# 기사 968/10000 (user_id: 387) 추천 완료.
# 기사 969/10000 (user_id: 335) 추천 완료.
# 기사 970/10000 (user_id: 191) 추천 완료.
# 기사 971/10000 (user_id: 321) 추천 완료.
# 기사 972/10000 (user_id: 341) 추천 완료.
# 기사 973/10000 (user_id: 436) 추천 완료.
# 기사 974/10000 (user_id: 432) 추천 완료.
# 기사 975/10000 (user_id: 423) 추천 완료.
# 기사 976/10000 (user_id: 328) 추천 완료.
# 기사 977/10000 (user_id: 197) 추천 완료.
# 기사 978/10000 (user_id: 434) 추천 완료.
# 기사 979/10000 (user_id: 171) 추천 완료.
# 기사 980/10000 (user_id: 243) 추천 완료.
# 기사 981/10000 (user_id: 334) 추천 완료.
# 기사 982/10000 (user_id: 286) 추천 완료.
# 기사 983/10000 (user_id: 218) 추천 완료.
# 기사 984/10000 (user_id: 314) 추천 완료.
# 기사 985/10000 (user_id: 365) 추천 완료.
# 기사 986/10000 (user_id: 358) 추천 완료.
# 기사 987/10000 (user_id: 364) 추천 완료.
# 기사 988/10000 (user_id: 408) 추천 완료.
# 기사 989/10000 (user_id: 321) 추천 완료.
# 기사 990/10000 (user_id: 350) 추천 완료.
# 기사 991/10000 (user_id: 190) 추천 완료.
# 기사 992/10000 (user_id: 379) 추천 완료.
# 기사 993/10000 (user_id: 291) 추천 완료.
# 기사 994/10000 (user_id: 319) 추천 완료.
# 기사 995/10000 (user_id: 381) 추천 완료.
# 기사 996/10000 (user_id: 384) 추천 완료.
# 기사 997/10000 (user_id: 390) 추천 완료.
# 기사 998/10000 (user_id: 179) 추천 완료.
# 기사 999/10000 (user_id: 285) 추천 완료.
# 기사 1000/10000 (user_id: 258) 추천 완료.
# 기사 1001/10000 (user_id: 297) 추천 완료.
# 기사 1002/10000 (user_id: 424) 추천 완료.
# 기사 1003/10000 (user_id: 359) 추천 완료.
# 기사 1004/10000 (user_id: 328) 추천 완료.
# 기사 1005/10000 (user_id: 401) 추천 완료.
# 기사 1006/10000 (user_id: 414) 추천 완료.
# 기사 1007/10000 (user_id: 345) 추천 완료.
# 기사 1008/10000 (user_id: 399) 추천 완료.
# 기사 1009/10000 (user_id: 333) 추천 완료.
# 기사 1010/10000 (user_id: 258) 추천 완료.
# 기사 1011/10000 (user_id: 265) 추천 완료.
# 기사 1012/10000 (user_id: 208) 추천 완료.
# 기사 1013/10000 (user_id: 416) 추천 완료.
# 기사 1242/10000 (user_id: 291) 추천 완료.
# 기사 1243/10000 (user_id: 251) 추천 완료.
# 기사 1244/10000 (user_id: 320) 추천 완료.
# 기사 1245/10000 (user_id: 383) 추천 완료.
# 기사 1246/10000 (user_id: 445) 추천 완료.
# 기사 1247/10000 (user_id: 209) 추천 완료.
# 기사 1248/10000 (user_id: 428) 추천 완료.
# 기사 1249/10000 (user_id: 171) 추천 완료.
# 기사 1250/10000 (user_id: 346) 추천 완료.
# 기사 1251/10000 (user_id: 386) 추천 완료.
# 기사 1252/10000 (user_id: 408) 추천 완료.
# 기사 1253/10000 (user_id: 249) 추천 완료.
# 기사 1254/10000 (user_id: 304) 추천 완료.
# 기사 1255/10000 (user_id: 270) 추천 완료.
# 기사 1256/10000 (user_id: 286) 추천 완료.
# 기사 1257/10000 (user_id: 168) 추천 완료.
# 기사 1258/10000 (user_id: 184) 추천 완료.
# 기사 1259/10000 (user_id: 385) 추천 완료.
# 중간 결과 저장: First_Route_Part_3.xlsx
# 기사 1260/10000 (user_id: 217) 추천 완료.
# 기사 1261/10000 (user_id: 336) 추천 완료.
# 기사 1262/10000 (user_id: 264) 추천 완료.
# 기사 1263/10000 (user_id: 292) 추천 완료.
# 기사 1264/10000 (user_id: 194) 추천 완료.
# 기사 1265/10000 (user_id: 376) 추천 완료.
# 기사 1266/10000 (user_id: 225) 추천 완료.
# 기사 1267/10000 (user_id: 345) 추천 완료.
# 기사 1268/10000 (user_id: 288) 추천 완료.
# 기사 1269/10000 (user_id: 184) 추천 완료.
# 기사 1270/10000 (user_id: 425) 추천 완료.
# 기사 1271/10000 (user_id: 324) 추천 완료.
# 기사 1272/10000 (user_id: 377) 추천 완료.
# 기사 1273/10000 (user_id: 183) 추천 완료.
# 기사 1274/10000 (user_id: 267) 추천 완료.
# 기사 1275/10000 (user_id: 322) 추천 완료.
# 기사 1276/10000 (user_id: 208) 추천 완료.
# 기사 1277/10000 (user_id: 288) 추천 완료.
# 기사 1278/10000 (user_id: 318) 추천 완료.
# 기사 1279/10000 (user_id: 285) 추천 완료.
# 기사 1280/10000 (user_id: 230) 추천 완료.
# 기사 1281/10000 (user_id: 375) 추천 완료.
# 기사 1282/10000 (user_id: 298) 추천 완료.
# 기사 1283/10000 (user_id: 435) 추천 완료.
# 기사 1284/10000 (user_id: 385) 추천 완료.
# 기사 1285/10000 (user_id: 425) 추천 완료.
# 기사 1286/10000 (user_id: 190) 추천 완료.
# 기사 1287/10000 (user_id: 202) 추천 완료.
# 기사 1288/10000 (user_id: 229) 추천 완료.
# 기사 1289/10000 (user_id: 332) 추천 완료.
# 기사 1290/10000 (user_id: 322) 추천 완료.
# 기사 1291/10000 (user_id: 381) 추천 완료.
# 기사 1292/10000 (user_id: 377) 추천 완료.
# 기사 1293/10000 (user_id: 313) 추천 완료.
# 기사 1294/10000 (user_id: 410) 추천 완료.
# 기사 1295/10000 (user_id: 364) 추천 완료.
# 기사 1296/10000 (user_id: 446) 추천 완료.
# 기사 1297/10000 (user_id: 387) 추천 완료.
# 기사 9949/10000 (user_id: 184) 추천 완료.
# 기사 9950/10000 (user_id: 336) 추천 완료.
# 기사 9951/10000 (user_id: 227) 추천 완료.
# 기사 9952/10000 (user_id: 361) 추천 완료.
# 기사 9953/10000 (user_id: 401) 추천 완료.
# 기사 9954/10000 (user_id: 442) 추천 완료.
# 기사 9955/10000 (user_id: 366) 추천 완료.
# 기사 9956/10000 (user_id: 287) 추천 완료.
# 기사 9957/10000 (user_id: 379) 추천 완료.
# 기사 9958/10000 (user_id: 458) 추천 완료.
# 기사 9959/10000 (user_id: 247) 추천 완료.
# 기사 9960/10000 (user_id: 421) 추천 완료.
# 기사 9961/10000 (user_id: 279) 추천 완료.
# 기사 9962/10000 (user_id: 447) 추천 완료.
# 기사 9963/10000 (user_id: 238) 추천 완료.
# 기사 9964/10000 (user_id: 195) 추천 완료.
# 기사 9965/10000 (user_id: 292) 추천 완료.
# 기사 9966/10000 (user_id: 263) 추천 완료.
# 기사 9967/10000 (user_id: 222) 추천 완료.
# 기사 9968/10000 (user_id: 412) 추천 완료.
# 기사 9969/10000 (user_id: 218) 추천 완료.
# 기사 9970/10000 (user_id: 329) 추천 완료.
# 기사 9971/10000 (user_id: 391) 추천 완료.
# 기사 9972/10000 (user_id: 320) 추천 완료.
# 기사 9973/10000 (user_id: 355) 추천 완료.
# 기사 9974/10000 (user_id: 351) 추천 완료.
# 기사 9975/10000 (user_id: 315) 추천 완료.
# 기사 9976/10000 (user_id: 279) 추천 완료.
# 기사 9977/10000 (user_id: 368) 추천 완료.
# 기사 9978/10000 (user_id: 288) 추천 완료.
# 기사 9979/10000 (user_id: 392) 추천 완료.
# 기사 9980/10000 (user_id: 305) 추천 완료.
# 기사 9981/10000 (user_id: 211) 추천 완료.
# 기사 9982/10000 (user_id: 321) 추천 완료.
# 기사 9983/10000 (user_id: 420) 추천 완료.
# 기사 9984/10000 (user_id: 294) 추천 완료.
# 기사 9985/10000 (user_id: 459) 추천 완료.
# 기사 9986/10000 (user_id: 442) 추천 완료.
# 기사 9987/10000 (user_id: 201) 추천 완료.
# 기사 9988/10000 (user_id: 420) 추천 완료.
# 기사 9989/10000 (user_id: 397) 추천 완료.
# 기사 9990/10000 (user_id: 436) 추천 완료.
# 기사 9991/10000 (user_id: 260) 추천 완료.
# 기사 9992/10000 (user_id: 416) 추천 완료.
# 기사 9993/10000 (user_id: 353) 추천 완료.
# 기사 9994/10000 (user_id: 168) 추천 완료.
# 기사 9995/10000 (user_id: 308) 추천 완료.
# 기사 9996/10000 (user_id: 261) 추천 완료.
# 기사 9997/10000 (user_id: 341) 추천 완료.
# 기사 9998/10000 (user_id: 329) 추천 완료.
# 기사 9999/10000 (user_id: 424) 추천 완료.
# 기사 10000/10000 (user_id: 224) 추천 완료.
# 최종 결과 저장: First_Route_Part_11.xlsx

# %%
import pandas as pd

def merge_excel_files_in_order(output_filename, total_parts):
    merged_data = []  # 데이터를 누적할 리스트

    for part_num in range(1, total_parts + 1):
        file_name = f"First_Route_Part_{part_num}.xlsx"
        print(f"병합 중: {file_name}")
        
        try:
            df = pd.read_excel(file_name)  # 각 파일 읽기
            merged_data.append(df)        # 데이터프레임 리스트에 추가
        except FileNotFoundError:
            print(f"파일을 찾을 수 없습니다: {file_name}")
            continue

    # 모든 데이터프레임 병합
    final_df = pd.concat(merged_data, ignore_index=True)

    # 병합된 데이터 저장
    final_df.to_excel(output_filename, index=False)
    print(f"모든 파일이 병합되어 저장되었습니다: {output_filename}")

# 병합 실행
merge_excel_files_in_order("First_Route.xlsx", 11)  # 11개 파일 병합
# Out:
# 병합 중: First_Route_Part_1.xlsx
# 병합 중: First_Route_Part_2.xlsx
# 병합 중: First_Route_Part_3.xlsx
# 병합 중: First_Route_Part_4.xlsx
# 병합 중: First_Route_Part_5.xlsx
# 병합 중: First_Route_Part_6.xlsx
# 병합 중: First_Route_Part_7.xlsx
# 병합 중: First_Route_Part_8.xlsx
# 병합 중: First_Route_Part_9.xlsx
# 병합 중: First_Route_Part_10.xlsx
# 병합 중: First_Route_Part_11.xlsx
# 모든 파일이 병합되어 저장되었습니다: First_Route.xlsx

# %%
first_route_df = pd.read_excel('First_Route.xlsx') 
first_route_df = first_route_df[~first_route_df['destination'].str.contains("제주")]
first_route_df.to_excel('First_Route.xlsx', index=False)

# %% [markdown]
# ### 1차 매칭 물류 사이의 경유지 찾기

# %%
from math import sqrt

def point_line_distance(x0, y0, x1, y1, x2, y2):
    """
    주어진 직선과 점 사이의 수직 거리를 계산
    - (x1, y1): 직선의 시작점
    - (x2, y2): 직선의 끝점
    - (x0, y0): 검사할 점
    """
    numerator = abs((y2 - y1) * x0 - (x2 - x1) * y0 + x2 * y1 - y2 * x1)
    denominator = sqrt((y2 - y1)**2 + (x2 - x1)**2)
    return numerator / denominator

def is_same_direction(x1, y1, x2, y2, x0_start, y0_start, x0_end, y0_end):
    """
    주어진 두 경로가 동일한 방향으로 진행하는지 확인합니다.
    x1, y1: 1차 물류 출발지
    x2, y2: 1차 물류 도착지
    x0_start, y0_start: 경유 물류 출발지
    x0_end, y0_end: 경유 물류 도착지
    """
    # 1차 물류의 진행 방향 (출발지 -> 도착지)
    main_lat_diff = x2 - x1
    main_long_diff = y2 - y1

    # 경유 물류의 진행 방향 (출발지 -> 도착지)
    inter_lat_diff = x0_end - x0_start
    inter_long_diff = y0_end - y0_start

    # 진행 방향 비교: 경로의 위도/경도 변화가 동일한지 확인
    return (
        (main_lat_diff * inter_lat_diff >= 0) and
        (main_long_diff * inter_long_diff >= 0)
    )

# %%
# 중간 경유지 물류 추천 함수
def find_intermediate_logistics(main_route, product_df, radius):
    intermediate_recommendations = []

    # main_route의 출발지와 도착지 좌표
    x1, y1 = main_route['departure_lat'], main_route['departure_long']
    x2, y2 = main_route['destination_lat'], main_route['destination_long']
    total_main_route_distance = calculate_distance(x1, y1, x2, y2)

    for _, logistics in product_df.iterrows():
        # 물류의 창고 위치 찾기
        x0_start, y0_start = logistics['departure_lat'], logistics['departure_long']
        x0_end, y0_end = logistics['destination_lat'], logistics['destination_long']

        # 출발지와 도착지 모두 직선 반경 내에 있는지 확인
        start_distance = point_line_distance(x0_start, y0_start, x1, y1, x2, y2)
        end_distance = point_line_distance(x0_end, y0_end, x1, y1, x2, y2)

        end_distance_c = calculate_distance(x0_end, y0_end, x2, y2)
        distance_ratio = end_distance_c / total_main_route_distance  # 중간 경유지 위주 추천 

        if start_distance <= radius and end_distance <= radius and 0.4 <= distance_ratio <= 0.7:
            # 방향이 동일한지 확인
            if is_same_direction(x1, y1, x2, y2, x0_start, y0_start, x0_end, y0_end):
                distance_to_logistics = calculate_distance(x0_start, y0_start, x0_end, y0_end)  # 물류 이동 거리...
                distance_to_warehouse = calculate_distance(x1, y1, x0_start, y0_start)
                distance_to_dest = calculate_distance(x0_end, y0_end, x2, y2)

                price = calculate_shipping_cost(logistics['weight'], distance_to_logistics)
                total_distance = distance_to_logistics + distance_to_dest + distance_to_warehouse

                normalized_distance = normalize(total_distance, 10, 400)
                normalized_price = normalize(price, 4, 70)

                distance_weight = 0.8
                price_weight = 1 - distance_weight

                score = (distance_weight * (1 - normalized_distance)) + (price_weight * normalized_price)

                # 추천 결과에 추가
                intermediate_recommendations.append({
                    "logistics": logistics,
                    "score": score,
                    "price": price,
                    "distance_to_warehouse": distance_to_warehouse,
                    "distance_to_dest": distance_to_dest,
                })

    # 추천 결과 중 score 기준 상위 n개만 선택
    n = 1
    intermediate_recommendations = sorted(
        intermediate_recommendations, key=lambda l: l['score'], reverse=True
    )[:n]

    return intermediate_recommendations

# 첫 번째 1차 추천 물류에 대해 경유지 물류 찾기
for main_logistics in recommended_logistics:
    logistics_series, score, distance_to_warehouse, distance_to_destination = main_logistics

    # Pandas Series를 dict처럼 활용
    intermediate_logistics = find_intermediate_logistics(logistics_series, product_df, 30)

    print(f"\n경유지 물류 추천 결과 for {logistics_series['product_id']} (1차 물류):")
    for item in intermediate_logistics:
        logistics = item["logistics"]  # item에서 logistics 추출
        score = item["score"]  # 점수 추출
        price = item["price"]
        distance_to_warehouse = item["distance_to_warehouse"]
        distance_to_dest = item["distance_to_dest"]

        # 물류 정보 출력
        print(f"  - 물류 ID: {logistics['product_id']}, 출발지: {logistics['departure']}, "
              f"도착지: {logistics['destination']}, 가격: {price}, 점수: {score:.2f}, "
              f"창고 거리: {distance_to_warehouse:.2f} km, 목적지 거리: {distance_to_dest:.2f} km")
# Out:
# 경유지 물류 추천 결과 for 6330 (1차 물류):
#   - 물류 ID: 9810, 출발지: 경기도 시흥시 만해로 43, 외 3필지 (정왕동), 도착지: 전라북도 군산시 서해로 194 (소룡동, 군산항제5부두), 가격: 31, 점수: 0.23, 창고 거리: 17.95 km, 목적지 거리: 157.20 km

# %%
import pandas as pd

# 1차 경로 정보 로드
first_route_df = pd.read_excel('First_Route.xlsx')  # 1차 경로 데이터
product_df = pd.read_excel('Dataset/PRODUCT.xlsx')  # 물류 데이터
warehouse_df = pd.read_excel('Dataset/WAREHOUSE.xlsx')  # 창고 데이터

stopover_results = []

def find_intermediate_logistics(main_route, product_df, warehouse_df, radius):
    intermediate_recommendations = []
    
    # main_route의 출발지와 도착지 좌표
    product_location = product_df[product_df['product_id'] == main_route['product_id']].iloc[0]
    x1, y1 = product_location['departure_lat'], product_location['departure_long']
    x2, y2 = product_location['destination_lat'], product_location['destination_long']
    total_main_route_distance = calculate_distance(x1, y1, x2, y2)
    
    if total_main_route_distance == 0:
        print(f"Warning: total_main_route_distance is 0 for product_id {main_route['product_id']}. Skipping this route.")
        return intermediate_recommendations  # 이 row는 건너뛰고 빈 결과 반환
    
    for _, logistics in product_df.iterrows():
        # 물류의 창고 위치 찾기
        x0_start, y0_start = logistics['departure_lat'], logistics['departure_long']
        x0_end, y0_end = logistics['destination_lat'], logistics['destination_long']
        
        # 출발지와 도착지 모두 직선 반경 내에 있는지 확인
        start_distance = point_line_distance(x0_start, y0_start, x1, y1, x2, y2)
        end_distance = point_line_distance(x0_end, y0_end, x1, y1, x2, y2)

        end_distance_c = calculate_distance(x0_end, y0_end, x2, y2)
        distance_ratio = end_distance_c / total_main_route_distance   # 중간쪽 경유지 위주 추천 
        
        if start_distance <= radius and end_distance <= radius and 0.4 <= distance_ratio <= 0.7:
            # 방향이 동일한지 확인
            if is_same_direction(x1, y1, x2, y2, x0_start, y0_start, x0_end, y0_end):
                distance_to_logistics = calculate_distance(x0_start, y0_start, x0_end, y0_end)  # 물류 이동 거리...
                distance_to_warehouse = calculate_distance(x1, y1, x0_start, y0_start)
                distance_to_dest = calculate_distance(x0_end, y0_end, x2, y2)
                
                price = calculate_shipping_cost(logistics['weight'], distance_to_logistics)
                total_distance = distance_to_logistics + distance_to_dest + distance_to_warehouse
                
                normalized_distance = normalize(total_distance, 10, 400)
                normalized_price = normalize(price, 4, 70)
                
                distance_weight = 0.8
                price_weight = 1 - distance_weight
                
                score = (distance_weight * (1 - normalized_distance)) + (price_weight * normalized_price)
                
                # 추천 결과에 추가
                intermediate_recommendations.append({
                    "logistics": logistics,
                    "score": score,
                    "price": price,
                    "distance_to_warehouse": distance_to_warehouse,
                    "distance_to_dest": distance_to_dest,
                })
                
    # 추천 결과 중 score 기준 상위 n개만 선택
    n = 1
    intermediate_recommendations = sorted(
        intermediate_recommendations, key=lambda l: l['score'], reverse=True
    )[:n]
    
    return intermediate_recommendations

# 모든 1차 경로에 대해 경유지 추천 수행
for idx, main_route in first_route_df.iterrows():
    intermediate_logistics = find_intermediate_logistics(main_route, product_df, warehouse_df, 30)
    for item in intermediate_logistics:
        logistics = item["logistics"]
        score = item["score"]
        price = item["price"]
        distance_to_warehouse = item["distance_to_warehouse"]
        distance_to_dest = item["distance_to_dest"]
        
        stopover_results.append({
            "main_product_id": main_route["product_id"],
            "main_departure": main_route["departure"],
            "main_destination": main_route["destination"],
            "prod_departure": main_route["prod_departure"],
            "prod_destination": main_route["prod_destination"],
            "stopover_product_id": logistics["product_id"],
            "stopover_departure": logistics["departure"],
            "stopover_destination": logistics["destination"],
            "distance_to_warehouse": distance_to_warehouse,
            "distance_to_dest": distance_to_dest,
            "score": score,
            "price": price
        })

    print(f"진행 상황: {idx + 1} / {len(first_route_df)} - 1차 물류 {main_route['product_id']}의 경유지 추천 완료.")

# 결과를 엑셀 파일로 저장
stopover_df = pd.DataFrame(stopover_results)
stopover_df.to_excel('First_Stopover.xlsx', index=False)
print("\n모든 경유지 추천 결과가 First_Stopover.xlsx 파일로 저장되었습니다.")
# Out:
# 진행 상황: 1 / 23786 - 1차 물류 746의 경유지 추천 완료.
# 진행 상황:
/ 23786 - 1차 물류 720의 경유지 추천 완료.
# 진행 상황: 991 / 23786 - 1차 물류 3010의 경유지 추천 완료.
# 진행 상황: 992 / 23786 - 1차 물류 5416의 경유지 추천 완료.
# 진행 상황: 993 / 23786 - 1차 물류 15071의 경유지 추천 완료.
# 진행 상황: 994 / 23786 - 1차 물류 7386의 경유지 추천 완료.
# 진행 상황: 995 / 23786 - 1차 물류 5859의 경유지 추천 완료.
# 진행 상황: 996 / 23786 - 1차 물류 7800의 경유지 추천 완료.
# 진행 상황: 997 / 23786 - 1차 물류 14548의 경유지 추천 완료.
# 진행 상황: 998 / 23786 - 1차 물류 10394의 경유지 추천 완료.
# 진행 상황: 999 / 23786 - 1차 물류 4925의 경유지 추천 완료.
# 진행 상황: 1000 / 23786 - 1차 물류 10439의 경유지 추천 완료.
# 진행 상황: 1001 / 23786 - 1차 물류 722의 경유지 추천 완료.
# 진행 상황: 1002 / 23786 - 1차 물류 6665의 경유지 추천 완료.
# 진행 상황: 1003 / 23786 - 1차 물류 12929의 경유지 추천 완료.
# 진행 상황: 1004 / 23786 - 1차 물류 7592의 경유지 추천 완료.
# 진행 상황: 1005 / 23786 - 1차 물류 7515의 경유지 추천 완료.
# 진행 상황: 1006 / 23786 - 1차 물류 4052의 경유지 추천 완료.
# 진행 상황: 1007 / 23786 - 1차 물류 10852의 경유지 추천 완료.
# 진행 상황: 1008 / 23786 - 1차 물류 9537의 경유지 추천 완료.
# 진행 상황: 1009 / 23786 - 1차 물류 9124의 경유지 추천 완료.
# 진행 상황: 1010 / 23786 - 1차 물류 8839의 경유지 추천 완료.
# 진행 상황: 1011 / 23786 - 1차 물류 7127의 경유지 추천 완료.
# 진행 상황: 1012 / 23786 - 1차 물류 2511의 경유지 추천 완료.
# 진행 상황: 1013 / 23786 - 1차 물류 9943의 경유지 추천 완료.
# 진행 상황: 1014 / 23786 - 1차 물류 9934의 경유지 추천 완료.
# 진행 상황: 1015 / 23786 - 1차 물류 13511의 경유지 추천 완료.
# 진행 상황: 1016 / 23786 - 1차 물류 13588의 경유지 추천 완료.
# 진행 상황: 1017 / 23786 - 1차 물류 13547의 경유지 추천 완료.
# 진행 상황: 1018 / 23786 - 1차 물류 14600의 경유지 추천 완료.
# 진행 상황: 1019 / 23786 - 1차 물류 14556의 경유지 추천 완료.
# 진행 상황: 1020 / 23786 - 1차 물류 14437의 경유지 추천 완료.
# 진행 상황: 1021 / 23786 - 1차 물류 3411의 경유지 추천 완료.
# 진행 상황: 1022 / 23786 - 1차 물류 6602의 경유지 추천 완료.
# 진행 상황: 1023 / 23786 - 1차 물류 12600의 경유지 추천 완료.
# 진행 상황: 1024 / 23786 - 1차 물류 11117의 경유지 추천 완료.
# 진행 상황: 1025 / 23786 - 1차 물류 1210의 경유지 추천 완료.
# 진행 상황: 1026 / 23786 - 1차 물류 414의 경유지 추천 완료.
# 진행 상황: 1027 / 23786 - 1차 물류 4996의 경유지 추천 완료.
# 진행 상황: 23782 / 23786 - 1차 물류 3051의 경유지 추천 완료.
# 진행 상황: 23783 / 23786 - 1차 물류 8415의 경유지 추천 완료.
# 진행 상황: 23784 / 23786 - 1차 물류 14235의 경유지 추천 완료.
# 진행 상황: 23785 / 23786 - 1차 물류 12566의 경유지 추천 완료.
# 진행 상황: 23786 / 23786 - 1차 물류 12917의 경유지 추천 완료.
#
# 모든 경유지 추천 결과가 First_Stopover.xlsx 파일로 저장되었습니다.

# %% [markdown]
# ### 2차 경유지 추천

# %%
import pandas as pd

# 데이터 로드
first_stopover_df = pd.read_excel('First_Stopover.xlsx')  # 1차 경유지 데이터
input_df = pd.read_excel('INPUT.xlsx')  # 각 물류의 user_id 정보를 포함한 데이터
product_df = pd.read_excel('Dataset/PRODUCT.xlsx')  # 물류 데이터
warehouse_df = pd.read_excel('Dataset/WAREHOUSE.xlsx')  # 창고 데이터

results = []  # 최종 결과 저장
intermediate_results = []  # 중간 저장용 리스트

def get_lat_long(product_id, product_df, location_type):
    product_row = product_df[product_df["product_id"] == product_id]
    if not product_row.empty:
        if location_type == "departure":
            return product_row.iloc[0]["departure_lat"], product_row.iloc[0]["departure_long"]
        elif location_type == "destination":
            return product_row.iloc[0]["destination_lat"], product_row.iloc[0]["destination_long"]
    return None, None  # 값이 없을 경우


def find_secondary_stop(main_route, first_stop, product_df, warehouse_df, radius, n=1):
    secondary_recommendations = []

    # 1차 경유지 도착지를 새로운 출발지로 설정
    first_stop_end_lat = first_stop["stopover_destination_lat"]
    first_stop_end_long = first_stop["stopover_destination_long"]

    # 원래 1차 물류의 최종 목적지
    main_route_dest_lat = main_route["main_destination_lat"]
    main_route_dest_long = main_route["main_destination_long"]

    for _, logistics in product_df.iterrows():
        # 물류의 창고 위치 찾기
        warehouse_location = warehouse_df[warehouse_df["USER_ID"] == logistics["user_id"]].iloc[0]
        x0_start, y0_start = warehouse_location["location_lat"], warehouse_location["location_long"]
        x0_end, y0_end = logistics["destination_lat"], logistics["destination_long"]

        # 출발지가 1차 경유지 도착지 반경 내에 있어야 함
        start_distance = calculate_distance(first_stop_end_lat, first_stop_end_long, x0_start, y0_start)
        end_distance = calculate_distance(x0_end, y0_end, main_route_dest_lat, main_route_dest_long)

        if start_distance <= radius and end_distance <= radius:
            # 방향이 일치하는지 확인
            if is_same_direction(
                first_stop_end_lat, first_stop_end_long,
                main_route_dest_lat, main_route_dest_long,
                x0_start, y0_start, x0_end, y0_end
            ):
                # 거리와 가격 계산
                distance_to_logistics = calculate_distance(x0_start, y0_start, x0_end, y0_end)
                price = calculate_shipping_cost(logistics["weight"], distance_to_logistics)

                normalized_distance = normalize(distance_to_logistics, 10, 400)
                normalized_price = normalize(price, 4, 70)

                # 기사의 선호도에 따른 가중치 조합
                distance_weight = 0.7
                price_weight = 1 - distance_weight

                score = (distance_weight * (1 - normalized_distance)) + (price_weight * normalized_price)

                # 추천 결과에 추가
                secondary_recommendations.append({
                    "logistics": logistics,
                    "score": score,
                    "price": price
                })

    # 상위 n개의 경유지 선택
    secondary_recommendations = secondary_recommendations[:n]

    return secondary_recommendations

# 순서대로 1차 경유지 데이터 처리
for idx, first_stop_row in first_stopover_df.iterrows():
    # user_id를 INPUT.xlsx에서 참조
    main_departure = first_stop_row["main_departure"]
    main_destination = first_stop_row["main_destination"]

    user_id_row = input_df[
        (input_df["departure"] == main_departure) &
        (input_df["destination"] == main_destination)
    ]

    if user_id_row.empty:
        print(f"Warning: No matching user_id found for departure={main_departure} and destination={main_destination}. Skipping...")
        continue

    user_id = user_id_row.iloc[0]["user_id"]

    # Main route 설정
    main_product_id = first_stop_row["main_product_id"]
    main_departure_lat, main_departure_long = get_lat_long(main_product_id, product_df, location_type="departure")
    main_destination_lat, main_destination_long = get_lat_long(main_product_id, product_df, location_type="destination")

    main_route = {
        "user_id": user_id,
        "main_product_id": main_product_id,
        "main_departure": main_departure,
        "main_destination": main_destination,
        "main_departure_lat": main_departure_lat,
        "main_departure_long": main_departure_long,
        "main_destination_lat": main_destination_lat,
        "main_destination_long": main_destination_long,
    }

    # 1차 경유지 정보
    stopover_product_id = first_stop_row["stopover_product_id"]
    stopover_departure_lat, stopover_departure_long = get_lat_long(stopover_product_id, product_df, location_type="departure")
    stopover_destination_lat, stopover_destination_long = get_lat_long(stopover_product_id, product_df, location_type="destination")

    first_stop = {
        "stopover_product_id": stopover_product_id,
        "stopover_departure": first_stop_row["stopover_departure"],
        "stopover_destination": first_stop_row["stopover_destination"],
        "stopover_departure_lat": stopover_departure_lat,
        "stopover_departure_long": stopover_departure_long,
        "stopover_destination_lat": stopover_destination_lat,
        "stopover_destination_long": stopover_destination_long,
        "score": first_stop_row["score"],
        "price": first_stop_row["price"],
    }

    # 2차 경유지 추천
    second_stops = find_secondary_stop(main_route, first_stop, product_df, warehouse_df, 50, n=1)
    if not second_stops:
        continue

    second_stop = second_stops[0]

    # 총 점수와 가격 계산
    total_score = first_stop["score"] + second_stop["score"]
    total_price = first_stop["price"] + second_stop["price"]

    # 결과 저장
    result_entry = {
        "user_id": main_route["user_id"],
        "main_product_id": main_route["main_product_id"],
        "main_departure": main_route["main_departure"],
        "main_destination": main_route["main_destination"],
        "stopover_id": first_stop["stopover_product_id"],
        "stopover_departure": first_stop["stopover_departure"],
        "stopover_destination": first_stop["stopover_destination"],
        "second_stop_id": second_stop["logistics"]["product_id"],
        "second_stop_departure": second_stop["logistics"]["departure"],
        "second_stop_destination": second_stop["logistics"]["destination"],
        "score": total_score,
        "price": total_price
    }

    results.append(result_entry)
    intermediate_results.append(result_entry)

    # 중간 저장: 첫 30개 결과 저장
    if len(intermediate_results) == 5:
        pd.DataFrame(intermediate_results).to_excel('Intermediate_30_Secondary_Stopover.xlsx', index=False)
        print(f"중간 결과 저장: Intermediate_30_Secondary_Stopover.xlsx")

    print(f"Processed row {idx + 1} / {len(first_stopover_df)}")

# 모든 결과를 엑셀 파일로 저장
results_df = pd.DataFrame(results)
results_df.to_excel('Final_Secondary_Stopover_Results.xlsx', index=False)
print("\n최종 결과가 Final_Secondary_Stopover_Results.xlsx 파일로 저장되었습니다.")
# Out:
# Processed row 1 / 23680
# Processed row 2 / 23680
# Processed row 3 / 23680
# Processed row 4 / 23680
# 중간 결과 저장: Intermediate_30_Secondary_Stopover.xlsx
# Processed row 5 / 23680
# Processed row 6 / 23680
# Processed row 7 / 23680
# Processed row 8 / 23680
# Processed row 9 / 23680
# Processed row 10 / 23680
# Processed row 16 / 23680
# Processed row 17 / 23680
# Processed row 18 / 23680
# Processed row 22 / 23680
# Processed row 23 / 23680
# Processed row 24 / 23680
# Processed row 28 / 23680
# Processed row 29 / 23680
# Processed row 30 / 23680
# Processed row 31 / 23680
# Processed row 32 / 23680
# Processed row 33 / 23680
# Processed row 34 / 23680
# Processed row 35 / 23680
# Processed row 36 / 23680
# Processed row 40 / 23680
# Processed row 41 / 23680
# Processed row 42 / 23680
# Processed row 45 / 23680
# Processed row 46 / 23680
# Processed row 48 / 23680
# Processed row 50 / 23680
# Processed row 51 / 23680
# Processed row 52 / 23680
# Processed row 53 / 23680
# Processed row 54 / 23680
# Processed row 55 / 23680
# Processed row 56 / 23680
# Processed row 57 / 23680
# Processed row 58 / 23680
# Processed row 62 / 23680
# Processed row 63 / 23680
# Processed row 64 / 23680
# Processed row 65 / 23680
# Processed row 66 / 23680
# Processed row 67 / 23680
# Processed row 68 / 23680
# Processed row 69 / 23680
# Processed row 70 / 23680
# Processed row 71 / 23680
# Processed row 72 / 23680
# Processed row 73 / 23680
# Processed row 74 / 23680
# Processed row 75 / 23680
# Processed row 76 / 23680
# Processed row 77 / 23680
# Processed row 78 / 23680
# Processed row 79 / 23680
# Processed row 81 / 23680
# Processed row 82 / 23680
# Processed row 83 / 23680
# Processed row 84 / 23680
# Processed row 85 / 23680
# Processed row 86 / 23680
# Processed row 87 / 23680
# Processed row 88 / 23680
# Processed row 92 / 23680
# Processed row 93 / 23680
# Processed row 94 / 23680
# Processed row 95 / 23680
# Processed row 96 / 23680
# Processed row 97 / 23680
# Processed row 98 / 23680
# Processed row 100 / 23680
# Processed row 101 / 23680
# Processed row 102 / 23680
# Processed row 106 / 23680
# Processed row 107 / 23680
# Processed row 108 / 23680
# Processed row 114 / 23680
# Processed row 115 / 23680
# Processed row 117 / 23680
# Processed row 119 / 23680
# Processed row 120 / 23680
# Processed row 121 / 23680
# Processed row 122 / 23680
# Processed row 123 / 23680
# Processed row 124 / 23680
# Processed row 127 / 23680
# Processed row 128 / 23680
# Processed row 129 / 23680
# Processed row 130 / 23680
# Processed row 131 / 23680
# Processed row 132 / 23680
# Processed row 133 / 23680
# Processed row 134 / 23680
# Processed row 135 / 23680
# Processed row 136 / 23680
# Processed row 137 / 23680
# Processed row 138 / 23680
# Processed row 139 / 23680
# Processed row 140 / 23680
# Processed row 142 / 23680
# Processed row 143 / 23680
# Processed row 144 / 23680
# Processed row 148 / 23680
# Processed row 150 / 23680
# Processed row 151 / 23680
# Processed row 152 / 23680
# Processed row 153 / 23680
# Processed row 154 / 23680
# Processed row 155 / 23680
# Processed row 156 / 23680
# Processed row 157 / 23680
# Processed row 158 / 23680
# Processed row 159 / 23680
# Processed row 160 / 23680
# Processed row 161 / 23680
# Processed row 162 / 23680
# Processed row 163 / 23680
# Processed row 164 / 23680
# Processed row 167 / 23680
# Processed row 168 / 23680
# Processed row 169 / 23680
# Processed row 170 / 23680
# Processed row 171 / 23680
# Processed row 172 / 23680
# Processed row 173 / 23680
# Processed row 174 / 23680
# Processed row 175 / 23680
# Processed row 176 / 23680
# Processed row 177 / 23680
# Processed row 178 / 23680
# Processed row 179 / 23680
# Processed row 180 / 23680
# Processed row 181 / 23680
# Processed row 182 / 23680
# Processed row 183 / 23680
# Processed row 184 / 23680
# Processed row 185 / 23680
# Processed row 186 / 23680
# Processed row 187 / 23680
# Processed row 188 / 23680
# Processed row 189 / 23680
# Processed row 190 / 23680
# Processed row 191 / 23680
# Processed row 192 / 23680
# Processed row 193 / 23680
# Processed row 197 / 23680
# Processed row 198 / 23680
# Processed row 199 / 23680
# Processed row 200 / 23680
# Processed row 201 / 23680
# Processed row 203 / 23680
# Processed row 205 / 23680
# Processed row 206 / 23680
# Processed row 207 / 23680
# Processed row 208 / 23680
# Processed row 209 / 23680
# Processed row 210 / 23680
# Processed row 211 / 23680
# Processed row 212 / 23680
# Processed row 213 / 23680
# Processed row 214 / 23680
# Processed row 215 / 23680
# Processed row 216 / 23680
# Processed row 217 / 23680
# Processed row 219 / 23680
# Processed row 220 / 23680
# Processed row 221 / 23680
# Processed row 225 / 23680
# Processed row 226 / 23680
# Processed row 230 / 23680
# Processed row 231 / 23680
# Processed row 232 / 23680
# Processed row 233 / 23680
# Processed row 237 / 23680
# Processed row 238 / 23680
# Processed row 239 / 23680
# Processed row 240 / 23680
# Processed row 241 / 23680
# Processed row 242 / 23680
# Processed row 246 / 23680
# Processed row 247 / 23680
# Processed row 248 / 23680
# Processed row 249 / 23680
# Processed row 250 / 23680
# Processed row 251 / 23680
# Processed row 252 / 23680
# Processed row 253 / 23680
# Processed row 254 / 23680
# Processed row 255 / 23680
# Processed row 256 / 23680
# Processed row 257 / 23680
# Processed row 261 / 23680
# Processed row 262 / 23680
# Processed row 263 / 23680
# Processed row 264 / 23680
# Processed row 265 / 23680
# Processed row 266 / 23680
# Processed row 270 / 23680
# Processed row 271 / 23680
# Processed row 272 / 23680
# Processed row 276 / 23680
# Processed row 277 / 23680
# Processed row 278 / 23680
# Processed row 279 / 23680
# Processed row 280 / 23680
# Processed row 281 / 23680
# Processed row 282 / 23680
# Processed row 283 / 23680
# Processed row 284 / 23680
# Processed row 285 / 23680
# Processed row 286 / 23680
# Processed row 289 / 23680
# Processed row 290 / 23680
# Processed row 291 / 23680
# Processed row 292 / 23680
# Processed row 293 / 23680
# Processed row 294 / 23680
# Processed row 295 / 23680
# Processed row 296 / 23680
# Processed row 297 / 23680
# Processed row 298 / 23680
# Processed row 299 / 23680
# Processed row 300 / 23680
# Processed row 304 / 23680
# Processed row 305 / 23680
# Processed row 306 / 23680
# Processed row 307 / 23680
# Processed row 308 / 23680
# Processed row 309 / 23680
# Processed row 310 / 23680
# Processed row 311 / 23680
# Processed row 312 / 23680
# Processed row 313 / 23680
# Processed row 314 / 23680
# Processed row 315 / 23680
# Processed row 316 / 23680
# Processed row 317 / 23680
# Processed row 318 / 23680
# Processed row 319 / 23680
# Processed row 320 / 23680
# Processed row 321 / 23680
# Processed row 322 / 23680
# Processed row 323 / 23680
# Processed row 324 / 23680
# Processed row 325 / 23680
# Processed row 326 / 23680
# Processed row 327 / 23680
# Processed row 328 / 23680
# Processed row 329 / 23680
# Processed row 330 / 23680
# Processed row 331 / 23680
# Processed row 332 / 23680
# Processed row 333 / 23680
# Processed row 334 / 23680
# Processed row 335 / 23680
# Processed row 336 / 23680
# Processed row 337 / 23680
# Processed row 338 / 23680
# Processed row 339 / 23680
# Processed row 340 / 23680
# Processed row 341 / 23680
# Processed row 345 / 23680
# Processed row 346 / 23680
# Processed row 347 / 23680
# Processed row 348 / 23680
# Processed row 349 / 23680
# Processed row 350 / 23680
# Processed row 353 / 23680
# Processed row 354 / 23680
# Processed row 355 / 23680
# Processed row 356 / 23680
# Processed row 357 / 23680
# Processed row 359 / 23680
# Processed row 360 / 23680
# Processed row 362 / 23680
# Processed row 368 / 23680
# Processed row 369 / 23680
# Processed row 370 / 23680
# Processed row 374 / 23680
# Processed row 375 / 23680
# Processed row 376 / 23680
# Processed row 377 / 23680
# Processed row 378 / 23680
# Processed row 379 / 23680
# Processed row 380 / 23680
# Processed row 381 / 23680
# Processed row 382 / 23680
# Processed row 383 / 23680
# Processed row 384 / 23680
# Processed row 385 / 23680
# Processed row 386 / 23680
# Processed row 387 / 23680
# Processed row 388 / 23680
# Processed row 389 / 23680
# Processed row 390 / 23680
# Processed row 391 / 23680
# Processed row 392 / 23680
# Processed row 393 / 23680
# Processed row 394 / 23680
# Processed row 395 / 23680
# Processed row 396 / 23680
# Processed row 397 / 23680
# Processed row 398 / 23680
# Processed row 399 / 23680
# Processed row 400 / 23680
# Processed row 401 / 23680
# Processed row 402 / 23680
# Processed row 403 / 23680
# Processed row 404 / 23680
# Processed row 405 / 23680
# Processed row 406 / 23680
# Processed row 407 / 23680
# Processed row 408 / 23680
# Processed row 409 / 23680
# Processed row 410 / 23680
# Processed row 411 / 23680
# Processed row 412 / 23680
# Processed row 413 / 23680
# Processed row 414 / 23680
# Processed row 415 / 23680
# Processed row 416 / 23680
# Processed row 417 / 23680
# Processed row 418 / 23680
# Processed row 419 / 23680
# Processed row 420 / 23680
# Processed row 421 / 23680
# Processed row 422 / 23680
# Processed row 423 / 23680
# Processed row 424 / 23680
# Processed row 425 / 23680
# Processed row 426 / 23680
# Processed row 427 / 23680
# Processed row 428 / 23680
# Processed row 429 / 23680
# Processed row 430 / 23680
# Processed row 431 / 23680
# Processed row 432 / 23680
# Processed row 433 / 23680
# Processed row 434 / 23680
# Processed row 435 / 23680
# Processed row 436 / 23680
# Processed row 437 / 23680
# Processed row 438 / 23680
# Processed row 439 / 23680
# Processed row 440 / 23680
# Processed row 441 / 23680
# Processed row 442 / 23680
# Processed row 443 / 23680
# Processed row 444 / 23680
# Processed row 445 / 23680
# Processed row 446 / 23680
# Processed row 447 / 23680
# Processed row 448 / 23680
# Processed row 449 / 23680
# Processed row 450 / 23680
# Processed row 451 / 23680
# Processed row 452 / 23680
# Processed row 453 / 23680
# Processed row 454 / 23680
# Processed row 455 / 23680
# Processed row 456 / 23680
# Processed row 457 / 23680
# Processed row 458 / 23680
# Processed row 459 / 23680
# Processed row 460 / 23680
# Processed row 461 / 23680
# Processed row 462 / 23680
# Processed row 463 / 23680
# Processed row 465 / 23680
# Processed row 466 / 23680
# Processed row 467 / 23680
# Processed row 468 / 23680
# Processed row 469 / 23680
# Processed row 470 / 23680
# Processed row 471 / 23680
# Processed row 472 / 23680
# Processed row 473 / 23680
# Processed row 474 / 23680
# Processed row 475 / 23680
# Processed row 476 / 23680
# Processed row 477 / 23680
# Processed row 478 / 23680
# Processed row 479 / 23680
# Processed row 480 / 23680
# Processed row 484 / 23680
# Processed row 485 / 23680
# Processed row 486 / 23680
# Processed row 487 / 23680
# Processed row 488 / 23680
# Processed row 489 / 23680
# Processed row 490 / 23680
# Processed row 491 / 23680
# Processed row 492 / 23680
# Processed row 496 / 23680
# Processed row 497 / 23680
# Processed row 498 / 23680
# Processed row 499 / 23680
# Processed row 500 / 23680
# Processed row 501 / 23680
# Processed row 502 / 23680
# Processed row 503 / 23680
# Processed row 504 / 23680
# Processed row 507 / 23680
# Processed row 508 / 23680
# Processed row 509 / 23680
# Processed row 510 / 23680
# Processed row 511 / 23680
# Processed row 512 / 23680
# Processed row 513 / 23680
# Processed row 514 / 23680
# Processed row 515 / 23680
# Processed row 516 / 23680
# Processed row 517 / 23680
# Processed row 518 / 23680
# Processed row 519 / 23680
# Processed row 520 / 23680
# Processed row 521 / 23680
# Processed row 522 / 23680
# Processed row 523 / 23680
# Processed row 524 / 23680
# Processed row 525 / 23680
# Processed row 526 / 23680
# Processed row 527 / 23680
# Processed row 528 / 23680
# Processed row 529 / 23680
# Processed row 533 / 23680
# Processed row 534 / 23680
# Processed row 535 / 23680
# Processed row 536 / 23680
# Processed row 537 / 23680
# Processed row 538 / 23680
# Processed row 539 / 23680
# Processed row 540 / 23680
# Processed row 542 / 23680
# Processed row 543 / 23680
# Processed row 544 / 23680
# Processed row 545 / 23680
# Processed row 546 / 23680
# Processed row 547 / 23680
# Processed row 548 / 23680
# Processed row 549 / 23680
# Processed row 550 / 23680
# Processed row 551 / 23680
# Processed row 552 / 23680
# Processed row 553 / 23680
# Processed row 554 / 23680
# Processed row 555 / 23680
# Processed row 556 / 23680
# Processed row 557 / 23680
# Processed row 558 / 23680
# Processed row 559 / 23680
# Processed row 560 / 23680
# Processed row 561 / 23680
# Processed row 562 / 23680
# Processed row 563 / 23680
# Processed row 564 / 23680
# Processed row 565 / 23680
# Processed row 566 / 23680
# Processed row 570 / 23680
# Processed row 572 / 23680
# Processed row 573 / 23680
# Processed row 574 / 23680
# Processed row 575 / 23680
# Processed row 576 / 23680
# Processed row 577 / 23680
# Processed row 578 / 23680
# Processed row 579 / 23680
# Processed row 580 / 23680
# Processed row 581 / 23680
# Processed row 582 / 23680
# Processed row 583 / 23680
# Processed row 584 / 23680
# Processed row 586 / 23680
# Processed row 587 / 23680
# Processed row 588 / 23680
# Processed row 589 / 23680
# Processed row 590 / 23680
# Processed row 591 / 23680
# Processed row 595 / 23680
# Processed row 596 / 23680
# Processed row 597 / 23680
# Processed row 598 / 23680
# Processed row 599 / 23680
# Processed row 600 / 23680
# Processed row 603 / 23680
# Processed row 604 / 23680
# Processed row 605 / 23680
# Processed row 606 / 23680
# Processed row 607 / 23680
# Processed row 608 / 23680
# Processed row 609 / 23680
# Processed row 610 / 23680
# Processed row 611 / 23680
# Processed row 612 / 23680
# Processed row 613 / 23680
# Processed row 614 / 23680
# Processed row 615 / 23680
# Processed row 616 / 23680
# Processed row 617 / 23680
# Processed row 619 / 23680
# Processed row 620 / 23680
# Processed row 621 / 23680
# Processed row 622 / 23680
# Processed row 623 / 23680
# Processed row 624 / 23680
# Processed row 626 / 23680
# Processed row 628 / 23680
# Processed row 629 / 23680
# Processed row 631 / 23680
# Processed row 632 / 23680
# Processed row 633 / 23680
# Processed row 634 / 23680
# Processed row 635 / 23680
# Processed row 636 / 23680
# Processed row 637 / 23680
# Processed row 638 / 23680
# Processed row 639 / 23680
# Processed row 640 / 23680
# Processed row 641 / 23680
# Processed row 642 / 23680
# Processed row 644 / 23680
# Processed row 645 / 23680
# Processed row 646 / 23680
# Processed row 653 / 23680
# Processed row 654 / 23680
# Processed row 655 / 23680
# Processed row 662 / 23680
# Processed row 663 / 23680
# Processed row 664 / 23680
# Processed row 665 / 23680
# Processed row 666 / 23680
# Processed row 667 / 23680
# Processed row 671 / 23680
# Processed row 672 / 23680
# Processed row 673 / 23680
# Processed row 674 / 23680
# Processed row 675 / 23680
# Processed row 676 / 23680
# Processed row 677 / 23680
# Processed row 678 / 23680
# Processed row 681 / 23680
# Processed row 682 / 23680
# Processed row 683 / 23680
# Processed row 685 / 23680
# Processed row 687 / 23680
# Processed row 688 / 23680
# Processed row 689 / 23680
# Processed row 690 / 23680
# Processed row 692 / 23680
# Processed row 693 / 23680
# Processed row 694 / 23680
# Processed row 695 / 23680
# Processed row 696 / 23680
# Processed row 697 / 23680
# Processed row 698 / 23680
# Processed row 701 / 23680
# Processed row 702 / 23680
# Processed row 703 / 23680
# Processed row 704 / 23680
# Processed row 708 / 23680
# Processed row 709 / 23680
# Processed row 710 / 23680
# Processed row 711 / 23680
# Processed row 712 / 23680
# Processed row 713 / 23680
# Processed row 714 / 23680
# Processed row 715 / 23680
# Processed row 716 / 23680
# Processed row 717 / 23680
# Processed row 718 / 23680
# Processed row 719 / 23680
# Processed row 722 / 23680
# Processed row 723 / 23680
# Processed row 724 / 23680
# Processed row 725 / 23680
# Processed row 726 / 23680
# Processed row 727 / 23680
# Processed row 728 / 23680
# Processed row 729 / 23680
# Processed row 730 / 23680
# Processed row 731 / 23680
# Processed row 732 / 23680
# Processed row 733 / 23680
# Processed row 734 / 23680
# Processed row 735 / 23680
# Processed row 736 / 23680
# Processed row 737 / 23680
# Processed row 738 / 23680
# Processed row 739 / 23680
# Processed row 740 / 23680
# Processed row 741 / 23680
# Processed row 742 / 23680
# Processed row 743 / 23680
# Processed row 744 / 23680
# Processed row 748 / 23680
# Processed row 749 / 23680
# Processed row 750 / 23680
# Processed row 754 / 23680
# Processed row 755 / 23680
# Processed row 756 / 23680
# Processed row 757 / 23680
# Processed row 758 / 23680
# Processed row 759 / 23680
# Processed row 769 / 23680
# Processed row 770 / 23680
# Processed row 771 / 23680
# Processed row 772 / 23680
# Processed row 774 / 23680
# Processed row 775 / 23680
# Processed row 776 / 23680
# Processed row 777 / 23680
# Processed row 778 / 23680
# Processed row 779 / 23680
# Processed row 780 / 23680
# Processed row 782 / 23680
# Processed row 784 / 23680
# Processed row 785 / 23680
# Processed row 786 / 23680
# Processed row 787 / 23680
# Processed row 788 / 23680
# Processed row 789 / 23680
# Processed row 790 / 23680
# Processed row 791 / 23680
# Processed row 792 / 23680
# Processed row 793 / 23680
# Processed row 794 / 23680
# Processed row 795 / 23680
# Processed row 796 / 23680
# Processed row 797 / 23680
# Processed row 798 / 23680
# Processed row 799 / 23680
# Processed row 800 / 23680
# Processed row 801 / 23680
# Processed row 802 / 23680
# Processed row 803 / 23680
# Processed row 805 / 23680
# Processed row 806 / 23680
# Processed row 807 / 23680
# Processed row 811 / 23680
# Processed row 812 / 23680
# Processed row 813 / 23680
# Processed row 814 / 23680
# Processed row 815 / 23680
# Processed row 816 / 23680
# Processed row 817 / 23680
# Processed row 818 / 23680
# Processed row 819 / 23680
# Processed row 821 / 23680
# Processed row 823 / 23680
# Processed row 824 / 23680
# Processed row 825 / 23680
# Processed row 826 / 23680
# Processed row 827 / 23680
# Processed row 828 / 23680
# Processed row 829 / 23680
# Processed row 830 / 23680
# Processed row 831 / 23680
# Processed row 833 / 23680
# Processed row 834 / 23680
# Processed row 835 / 23680
# Processed row 836 / 23680
# Processed row 837 / 23680
# Processed row 841 / 23680
# Processed row 842 / 23680
# Processed row 843 / 23680
# Processed row 844 / 23680
# Processed row 845 / 23680
# Processed row 847 / 23680
# Processed row 848 / 23680
# Processed row 849 / 23680
# Processed row 850 / 23680
# Processed row 851 / 23680
# Processed row 852 / 23680
# Processed row 853 / 23680
# Processed row 854 / 23680
# Processed row 855 / 23680
# Processed row 856 / 23680
# Processed row 857 / 23680
# Processed row 858 / 23680
# Processed row 865 / 23680
# Processed row 866 / 23680
# Processed row 867 / 23680
# Processed row 868 / 23680
# Processed row 869 / 23680
# Processed row 870 / 23680
# Processed row 874 / 23680
# Processed row 875 / 23680
# Processed row 876 / 23680
# Processed row 877 / 23680
# Processed row 878 / 23680
# Processed row 879 / 23680
# Processed row 883 / 23680
# Processed row 884 / 23680
# Processed row 885 / 23680
# Processed row 886 / 23680
# Processed row 887 / 23680
# Processed row 888 / 23680
# Processed row 892 / 23680
# Processed row 898 / 23680
# Processed row 899 / 23680
# Processed row 900 / 23680
# Processed row 901 / 23680
# Processed row 905 / 23680
# Processed row 906 / 23680
# Processed row 907 / 23680
# Processed row 908 / 23680
# Processed row 909 / 23680
# Processed row 910 / 23680
# Processed row 911 / 23680
# Processed row 912 / 23680
# Processed row 913 / 23680
# Processed row 915 / 23680
# Processed row 916 / 23680
# Processed row 917 / 23680
# Processed row 918 / 23680
# Processed row 919 / 23680
# Processed row 920 / 23680
# Processed row 921 / 23680
# Processed row 922 / 23680
# Processed row 923 / 23680
# Processed row 924 / 23680
# Processed row 925 / 23680
# Processed row 926 / 23680
# Processed row 927 / 23680
# Processed row 928 / 23680
# Processed row 929 / 23680
# Processed row 930 / 23680
# Processed row 931 / 23680
# Processed row 932 / 23680
# Processed row 933 / 23680
# Processed row 934 / 23680
# Processed row 935 / 23680
# Processed row 937 / 23680
# Processed row 938 / 23680
# Processed row 939 / 23680
# Processed row 940 / 23680
# Processed row 941 / 23680
# Processed row 942 / 23680
# Processed row 943 / 23680
# Processed row 944 / 23680
# Processed row 945 / 23680
# Processed row 946 / 23680
# Processed row 947 / 23680
# Processed row 948 / 23680
# Processed row 949 / 23680
# Processed row 950 / 23680
# Processed row 951 / 23680
# Processed row 952 / 23680
# Processed row 953 / 23680
# Processed row 954 / 23680
# Processed row 955 / 23680
# Processed row 956 / 23680
# Processed row 957 / 23680
# Processed row 958 / 23680
# Processed row 959 / 23680
# Processed row 960 / 23680
# Processed row 961 / 23680
# Processed row 962 / 23680
# Processed row 963 / 23680
# Processed row 964 / 23680
# Processed row 965 / 23680
# Processed row 966 / 23680
# Processed row 967 / 23680
# Processed row 968 / 23680
# Processed row 969 / 23680
# Processed row 970 / 23680
# Processed row 971 / 23680
# Processed row 972 / 23680
# Processed row 973 / 23680
# Processed row 974 / 23680
# Processed row 975 / 23680
# Processed row 976 / 23680
# Processed row 977 / 23680
# Processed row 978 / 23680
# Processed row 979 / 23680
# Processed row 980 / 23680
# Processed row 981 / 23680
# Processed row 982 / 23680
# Processed row 983 / 23680
# Processed row 984 / 23680
# Processed row 987 / 23680
# Processed row 988 / 23680
# Processed row 989 / 23680
# Processed row 990 / 23680
# Processed row 991 / 23680
# Processed row 992 / 23680
# Processed row 993 / 23680
# Processed row 994 / 23680
# Processed row 995 / 23680
# Processed row 996 / 23680
# Processed row 997 / 23680
# Processed row 998 / 23680
# Processed row 999 / 23680
# Processed row 1000 / 23680
# Processed row 1001 / 23680
# Processed row 1002 / 23680
# Processed row 1003 / 23680
# Processed row 1004 / 23680
# Processed row 1005 / 23680
# Processed row 1006 / 23680
# Processed row 1007 / 23680
# Processed row 1008 / 23680
# Processed row 1011 / 23680
# Processed row 1012 / 23680
# Processed row 1016 / 23680
# Processed row 1017 / 23680
# Processed row 1018 / 23680
# Processed row 1019 / 23680
# Processed row 1020 / 23680
# Processed row 1021 / 23680
# Processed row 1022 / 23680
# Processed row 1023 / 23680
# Processed row 1024 / 23680
# Processed row 1025 / 23680
# Processed row 1026 / 23680
# Processed row 1027 / 23680
# Processed row 1035 / 23680
# Processed row 1037 / 23680
# Processed row 1038 / 23680
# Processed row 1039 / 23680
# Processed row 1040 / 23680
# Processed row 1041 / 23680
# Processed row 1042 / 23680
# Processed row 1049 / 23680
# Processed row 1051 / 23680
# Processed row 1052 / 23680
# Processed row 1053 / 23680
# Processed row 1054 / 23680
# Processed row 1058 / 23680
# Processed row 1060 / 23680
# Processed row 1063 / 23680
# Processed row 1064 / 23680
# Processed row 1065 / 23680
# Processed row 1066 / 23680
# Processed row 1067 / 23680
# Processed row 1068 / 23680
# Processed row 1069 / 23680
# Processed row 1070 / 23680
# Processed row 1072 / 23680
# Processed row 1073 / 23680
# Processed row 1077 / 23680
# Processed row 1078 / 23680
# Processed row 1079 / 23680
# Processed row 1080 / 23680
# Processed row 1081 / 23680
# Processed row 1082 / 23680
# Processed row 1083 / 23680
# Processed row 1084 / 23680
# Processed row 1085 / 23680
# Processed row 1086 / 23680
# Processed row 1087 / 23680
# Processed row 1088 / 23680
# Processed row 1089 / 23680
# Processed row 1090 / 23680
# Processed row 1091 / 23680
# Processed row 1092 / 23680
# Processed row 1093 / 23680
# Processed row 1094 / 23680
# Processed row 1095 / 23680
# Processed row 1096 / 23680
# Processed row 1097 / 23680
# Processed row 1098 / 23680
# Processed row 1099 / 23680
# Processed row 1100 / 23680
# Processed row 1104 / 23680
# Processed row 1105 / 23680
# Processed row 1106 / 23680
# Processed row 1108 / 23680
# Processed row 1109 / 23680
# Processed row 1110 / 23680
# Processed row 1111 / 23680
# Processed row 1112 / 23680
# Processed row 1113 / 23680
# Processed row 1114 / 23680
# Processed row 1115 / 23680
# Processed row 1116 / 23680
# Processed row 1117 / 23680
# Processed row 1118 / 23680
# Processed row 1119 / 23680
# Processed row 1120 / 23680
# Processed row 1121 / 23680
# Processed row 1122 / 23680
# Processed row 1123 / 23680
# Processed row 1124 / 23680
# Processed row 1125 / 23680
# Processed row 1127 / 23680
# Processed row 1128 / 23680
# Processed row 1129 / 23680
# Processed row 1131 / 23680
# Processed row 1132 / 23680
# Processed row 1133 / 23680
# Processed row 1134 / 23680
# Processed row 1135 / 23680
# Processed row 1137 / 23680
# Processed row 1138 / 23680
# Processed row 1139 / 23680
# Processed row 1141 / 23680
# Processed row 1142 / 23680
# Processed row 1143 / 23680
# Processed row 1144 / 23680
# Processed row 1145 / 23680
# Processed row 1146 / 23680
# Processed row 1147 / 23680
# Processed row 1148 / 23680
# Processed row 1149 / 23680
# Processed row 1150 / 23680
# Processed row 1151 / 23680
# Processed row 1152 / 23680
# Processed row 1156 / 23680
# Processed row 1157 / 23680
# Processed row 1158 / 23680
# Processed row 1159 / 23680
# Processed row 1160 / 23680
# Processed row 1161 / 23680
# Processed row 1162 / 23680
# Processed row 1163 / 23680
# Processed row 1164 / 23680
# Processed row 1165 / 23680
# Processed row 1166 / 23680
# Processed row 1167 / 23680
# Processed row 1168 / 23680
# Processed row 1169 / 23680
# Processed row 1170 / 23680
# Processed row 1171 / 23680
# Processed row 1172 / 23680
# Processed row 1173 / 23680
# Processed row 1174 / 23680
# Processed row 1175 / 23680
# Processed row 1176 / 23680
# Processed row 1177 / 23680
# Processed row 1178 / 23680
# Processed row 1179 / 23680
# Processed row 1180 / 23680
# Processed row 1181 / 23680
# Processed row 1182 / 23680
# Processed row 1183 / 23680
# Processed row 1184 / 23680
# Processed row 1185 / 23680
# Processed row 1186 / 23680
# Processed row 1187 / 23680
# Processed row 1188 / 23680
# Processed row 1189 / 23680
# Processed row 1190 / 23680
# Processed row 1191 / 23680
# Processed row 1193 / 23680
# Processed row 1195 / 23680
# Processed row 1196 / 23680
# Processed row 1197 / 23680
# Processed row 1198 / 23680
# Processed row 1199 / 23680
# Processed row 1200 / 23680
# Processed row 1201 / 23680
# Processed row 1202 / 23680
# Processed row 1203 / 23680
# Processed row 1210 / 23680
# Processed row 1211 / 23680
# Processed row 1212 / 23680
# Processed row 1213 / 23680
# Processed row 1214 / 23680
# Processed row 1215 / 23680
# Processed row 1216 / 23680
# Processed row 1217 / 23680
# Processed row 1218 / 23680
# Processed row 1220 / 23680
# Processed row 1221 / 23680
# Processed row 1222 / 23680
# Processed row 1223 / 23680
# Processed row 1224 / 23680
# Processed row 1228 / 23680
# Processed row 1229 / 23680
# Processed row 1230 / 23680
# Processed row 1231 / 23680
# Processed row 1232 / 23680
# Processed row 1233 / 23680
# Processed row 1234 / 23680
# Processed row 1235 / 23680
# Processed row 1236 / 23680
# Processed row 1237 / 23680
# Processed row 1238 / 23680
# Processed row 1240 / 23680
# Processed row 1242 / 23680
# Processed row 1243 / 23680
# Processed row 1244 / 23680
# Processed row 1245 / 23680
# Processed row 1246 / 23680
# Processed row 1247 / 23680
# Processed row 1248 / 23680
# Processed row 1249 / 23680
# Processed row 1250 / 23680
# Processed row 1251 / 23680
# Processed row 1252 / 23680
# Processed row 1253 / 23680
# Processed row 1254 / 23680
# Processed row 1255 / 23680
# Processed row 1256 / 23680
# Processed row 1257 / 23680
# Processed row 1258 / 23680
# Processed row 1259 / 23680
# Processed row 1260 / 23680
# Processed row 1261 / 23680
# Processed row 1262 / 23680
# Processed row 1263 / 23680
# Processed row 1264 / 23680
# Processed row 1265 / 23680
# Processed row 1266 / 23680
# Processed row 1269 / 23680
# Processed row 1270 / 23680
# Processed row 1271 / 23680
# Processed row 1272 / 23680
# Processed row 1273 / 23680
# Processed row 1274 / 23680
# Processed row 1275 / 23680
# Processed row 1276 / 23680
# Processed row 1277 / 23680
# Processed row 1278 / 23680
# Processed row 1279 / 23680
# Processed row 1280 / 23680
# Processed row 1281 / 23680
# Processed row 1282 / 23680
# Processed row 1283 / 23680
# Processed row 1284 / 23680
# Processed row 1285 / 23680
# Processed row 1286 / 23680
# Processed row 1287 / 23680
# Processed row 1288 / 23680
# Processed row 1289 / 23680
# Processed row 1290 / 23680
# Processed row 1294 / 23680
# Processed row 1295 / 23680
# Processed row 1296 / 23680
# Processed row 1298 / 23680
# Processed row 1299 / 23680
# Processed row 1300 / 23680
# Processed row 1301 / 23680
# Processed row 1302 / 23680
# Processed row 1303 / 23680
# Processed row 1304 / 23680
# Processed row 1305 / 23680
# Processed row 1306 / 23680
# Processed row 1307 / 23680
# Processed row 1308 / 23680
# Processed row 1309 / 23680
# Processed row 1311 / 23680
# Processed row 1312 / 23680
# Processed row 1313 / 23680
# Processed row 1314 / 23680
# Processed row 1315 / 23680
# Processed row 1316 / 23680
# Processed row 1317 / 23680
# Processed row 1318 / 23680
# Processed row 1319 / 23680
# Processed row 1320 / 23680
# Processed row 1321 / 23680
# Processed row 1322 / 23680
# Processed row 1323 / 23680
# Processed row 1326 / 23680
# Processed row 1327 / 23680
# Processed row 1328 / 23680
# Processed row 1329 / 23680
# Processed row 1330 / 23680
# Processed row 1331 / 23680
# Processed row 1332 / 23680
# Processed row 1333 / 23680
# Processed row 1334 / 23680
# Processed row 1335 / 23680
# Processed row 1336 / 23680
# Processed row 1338 / 23680
# Processed row 1340 / 23680
# Processed row 1341 / 23680
# Processed row 1342 / 23680
# Processed row 1343 / 23680
# Processed row 1344 / 23680
# Processed row 1345 / 23680
# Processed row 1346 / 23680
# Processed row 1347 / 23680
# Processed row 1348 / 23680
# Processed row 1350 / 23680
# Processed row 1351 / 23680
# Processed row 1352 / 23680
# Processed row 1353 / 23680
# Processed row 1357 / 23680
# Processed row 1360 / 23680
# Processed row 1364 / 23680
# Processed row 1365 / 23680
# Processed row 1366 / 23680
# Processed row 1367 / 23680
# Processed row 1368 / 23680
# Processed row 1369 / 23680
# Processed row 1372 / 23680
# Processed row 1373 / 23680
# Processed row 1374 / 23680
# Processed row 1375 / 23680
# Processed row 1376 / 23680
# Processed row 1377 / 23680
# Processed row 1378 / 23680
# Processed row 1379 / 23680
# Processed row 1380 / 23680
# Processed row 1381 / 23680
# Processed row 1382 / 23680
# Processed row 1383 / 23680
# Processed row 1384 / 23680
# Processed row 1385 / 23680
# Processed row 1386 / 23680
# Processed row 1387 / 23680
# Processed row 1388 / 23680
# Processed row 1389 / 23680
# Processed row 1390 / 23680
# Processed row 1391 / 23680
# Processed row 1392 / 23680
# Processed row 1393 / 23680
# Processed row 1394 / 23680
# Processed row 1396 / 23680
# Processed row 1397 / 23680
# Processed row 1399 / 23680
# Processed row 1400 / 23680
# Processed row 1401 / 23680
# Processed row 1403 / 23680
# Processed row 1404 / 23680
# Processed row 1405 / 23680
# Processed row 1406 / 23680
# Processed row 1407 / 23680
# Processed row 1408 / 23680
# Processed row 1409 / 23680
# Processed row 1410 / 23680
# Processed row 1411 / 23680
# Processed row 1412 / 23680
# Processed row 1415 / 23680
# Processed row 1416 / 23680
# Processed row 1417 / 23680
# Processed row 1419 / 23680
# Processed row 1420 / 23680
# Processed row 1421 / 23680
# Processed row 1423 / 23680
# Processed row 1424 / 23680
# Processed row 1425 / 23680
# Processed row 1426 / 23680
# Processed row 1427 / 23680
# Processed row 1428 / 23680
# Processed row 1429 / 23680
# Processed row 1430 / 23680
# Processed row 1431 / 23680
# Processed row 1432 / 23680
# Processed row 1433 / 23680
# Processed row 1434 / 23680
# Processed row 1435 / 23680
# Processed row 1436 / 23680
# Processed row 1437 / 23680
# Processed row 1438 / 23680
# Processed row 1439 / 23680
# Processed row 1443 / 23680
# Processed row 1444 / 23680
# Processed row 1445 / 23680
# Processed row 1446 / 23680
# Processed row 1447 / 23680
# Processed row 1448 / 23680
# Processed row 1450 / 23680
# Processed row 1451 / 23680
# Processed row 1452 / 23680
# Processed row 1453 / 23680
# Processed row 1454 / 23680
# Processed row 1455 / 23680
# Processed row 1456 / 23680
# Processed row 1457 / 23680
# Processed row 1458 / 23680
# Processed row 1459 / 23680
# Processed row 1460 / 23680
# Processed row 1461 / 23680
# Processed row 1462 / 23680
# Processed row 1463 / 23680
# Processed row 1464 / 23680
# Processed row 1465 / 23680
# Processed row 1466 / 23680
# Processed row 1468 / 23680
# Processed row 1469 / 23680
# Processed row 1470 / 23680
# Processed row 1472 / 23680
# Processed row 1473 / 23680
# Processed row 1474 / 23680
# Processed row 1475 / 23680
# Processed row 1476 / 23680
# Processed row 1477 / 23680
# Processed row 1478 / 23680
# Processed row 1479 / 23680
# Processed row 1480 / 23680
# Processed row 1481 / 23680
# Processed row 1482 / 23680
# Processed row 1483 / 23680
# Processed row 1484 / 23680
# Processed row 1485 / 23680
# Processed row 1486 / 23680
# Processed row 1487 / 23680
# Processed row 1488 / 23680
# Processed row 1489 / 23680
# Processed row 1490 / 23680
# Processed row 1491 / 23680
# Processed row 1492 / 23680
# Processed row 1493 / 23680
# Processed row 1494 / 23680
# Processed row 1495 / 23680
# Processed row 1496 / 23680
# Processed row 1497 / 23680
# Processed row 1498 / 23680
# Processed row 1499 / 23680
# Processed row 1500 / 23680
# Processed row 1501 / 23680
# Processed row 1502 / 23680
# Processed row 1503 / 23680
# Processed row 1504 / 23680
# Processed row 1505 / 23680
# Processed row 1506 / 23680
# Processed row 1507 / 23680
# Processed row 1508 / 23680
# Processed row 1509 / 23680
# Processed row 1510 / 23680
# Processed row 1511 / 23680
# Processed row 1512 / 23680
# Processed row 1513 / 23680
# Processed row 1514 / 23680
# Processed row 1521 / 23680
# Processed row 1522 / 23680
# Processed row 1523 / 23680
# Processed row 1524 / 23680
# Processed row 1525 / 23680
# Processed row 1526 / 23680
# Processed row 1527 / 23680
# Processed row 1528 / 23680
# Processed row 1529 / 23680
# Processed row 1530 / 23680
# Processed row 1533 / 23680
# Processed row 1537 / 23680
# Processed row 1538 / 23680
# Processed row 1539 / 23680
# Processed row 1543 / 23680
# Processed row 1544 / 23680
# Processed row 1545 / 23680
# Processed row 1546 / 23680
# Processed row 1547 / 23680
# Processed row 1548 / 23680
# Processed row 1549 / 23680
# Processed row 1553 / 23680
# Processed row 1554 / 23680
# Processed row 1555 / 23680
# Processed row 1556 / 23680
# Processed row 1557 / 23680
# Processed row 1558 / 23680
# Processed row 1562 / 23680
# Processed row 1563 / 23680
# Processed row 1564 / 23680
# Processed row 1565 / 23680
# Processed row 1566 / 23680
# Processed row 1567 / 23680
# Processed row 1574 / 23680
# Processed row 1575 / 23680
# Processed row 1576 / 23680
# Processed row 1577 / 23680
# Processed row 1578 / 23680
# Processed row 1579 / 23680
# Processed row 1580 / 23680
# Processed row 1581 / 23680
# Processed row 1582 / 23680
# Processed row 1583 / 23680
# Processed row 1584 / 23680
# Processed row 1585 / 23680
# Processed row 1586 / 23680
# Processed row 1587 / 23680
# Processed row 1588 / 23680
# Processed row 1589 / 23680
# Processed row 1590 / 23680
# Processed row 1591 / 23680
# Processed row 1592 / 23680
# Processed row 1593 / 23680
# Processed row 1594 / 23680
# Processed row 1595 / 23680
# Processed row 1596 / 23680
# Processed row 1597 / 23680
# Processed row 1598 / 23680
# Processed row 1599 / 23680
# Processed row 1600 / 23680
# Processed row 1601 / 23680
# Processed row 1602 / 23680
# Processed row 1603 / 23680
# Processed row 1604 / 23680
# Processed row 1605 / 23680
# Processed row 1606 / 23680
# Processed row 1610 / 23680
# Processed row 1611 / 23680
# Processed row 1612 / 23680
# Processed row 1613 / 23680
# Processed row 1616 / 23680
# Processed row 1617 / 23680
# Processed row 1618 / 23680
# Processed row 1619 / 23680
# Processed row 1623 / 23680
# Processed row 1624 / 23680
# Processed row 1625 / 23680
# Processed row 1626 / 23680
# Processed row 1628 / 23680
# Processed row 1629 / 23680
# Processed row 1630 / 23680
# Processed row 1631 / 23680
# Processed row 1632 / 23680
# Processed row 1633 / 23680
# Processed row 1634 / 23680
# Processed row 1635 / 23680
# Processed row 1640 / 23680
# Processed row 1641 / 23680
# Processed row 1642 / 23680
# Processed row 1643 / 23680
# Processed row 1644 / 23680
# Processed row 1645 / 23680
# Processed row 1646 / 23680
# Processed row 1647 / 23680
# Processed row 1648 / 23680
# Processed row 1655 / 23680
# Processed row 1656 / 23680
# Processed row 1657 / 23680
# Processed row 1658 / 23680
# Processed row 1659 / 23680
# Processed row 1660 / 23680
# Processed row 1661 / 23680
# Processed row 1662 / 23680
# Processed row 1664 / 23680
# Processed row 1665 / 23680
# Processed row 1666 / 23680
# Processed row 1670 / 23680
# Processed row 1671 / 23680
# Processed row 1672 / 23680
# Processed row 1673 / 23680
# Processed row 1676 / 23680
# Processed row 1677 / 23680
# Processed row 1678 / 23680
# Processed row 1679 / 23680
# Processed row 1680 / 23680
# Processed row 1681 / 23680
# Processed row 1682 / 23680
# Processed row 1683 / 23680
# Processed row 1684 / 23680
# Processed row 1685 / 23680
# Processed row 1686 / 23680
# Processed row 1687 / 23680
# Processed row 1689 / 23680
# Processed row 1693 / 23680
# Processed row 1694 / 23680
# Processed row 1695 / 23680
# Processed row 1696 / 23680
# Processed row 1697 / 23680
# Processed row 1698 / 23680
# Processed row 1699 / 23680
# Processed row 1700 / 23680
# Processed row 1701 / 23680
# Processed row 1702 / 23680
# Processed row 1703 / 23680
# Processed row 1704 / 23680
# Processed row 1705 / 23680
# Processed row 1706 / 23680
# Processed row 1707 / 23680
# Processed row 1714 / 23680
# Processed row 1715 / 23680
# Processed row 1716 / 23680
# Processed row 1717 / 23680
# Processed row 1718 / 23680
# Processed row 1719 / 23680
# Processed row 1720 / 23680
# Processed row 1721 / 23680
# Processed row 1723 / 23680
# Processed row 1724 / 23680
# Processed row 1725 / 23680
# Processed row 1726 / 23680
# Processed row 1727 / 23680
# Processed row 1728 / 23680
# Processed row 1729 / 23680
# Processed row 1730 / 23680
# Processed row 1731 / 23680
# Processed row 1732 / 23680
# Processed row 1733 / 23680
# Processed row 1734 / 23680
# Processed row 1735 / 23680
# Processed row 1736 / 23680
# Processed row 1737 / 23680
# Processed row 1738 / 23680
# Processed row 1739 / 23680
# Processed row 1740 / 23680
# Processed row 1741 / 23680
# Processed row 1742 / 23680
# Processed row 1743 / 23680
# Processed row 1744 / 23680
# Processed row 1745 / 23680
# Processed row 1746 / 23680
# Processed row 1747 / 23680
# Processed row 1748 / 23680
# Processed row 1749 / 23680
# Processed row 1750 / 23680
# Processed row 1751 / 23680
# Processed row 1755 / 23680
# Processed row 1756 / 23680
# Processed row 1757 / 23680
# Processed row 1758 / 23680
# Processed row 1759 / 23680
# Processed row 1760 / 23680
# Processed row 1761 / 23680
# Processed row 1762 / 23680
# Processed row 1763 / 23680
# Processed row 1766 / 23680
# Processed row 1771 / 23680
# Processed row 1772 / 23680
# Processed row 1773 / 23680
# Processed row 1774 / 23680
# Processed row 1777 / 23680
# Processed row 1778 / 23680
# Processed row 1779 / 23680
# Processed row 1780 / 23680
# Processed row 1781 / 23680
# Processed row 1782 / 23680
# Processed row 1783 / 23680
# Processed row 1784 / 23680
# Processed row 1785 / 23680
# Processed row 1786 / 23680
# Processed row 1787 / 23680
# Processed row 1788 / 23680
# Processed row 1789 / 23680
# Processed row 1790 / 23680
# Processed row 1791 / 23680
# Processed row 1793 / 23680
# Processed row 1794 / 23680
# Processed row 1795 / 23680
# Processed row 1796 / 23680
# Processed row 1797 / 23680
# Processed row 1798 / 23680
# Processed row 1799 / 23680
# Processed row 1800 / 23680
# Processed row 1804 / 23680
# Processed row 1805 / 23680
# Processed row 1806 / 23680
# Processed row 1807 / 23680
# Processed row 1808 / 23680
# Processed row 1809 / 23680
# Processed row 1810 / 23680
# Processed row 1811 / 23680
# Processed row 1812 / 23680
# Processed row 1813 / 23680
# Processed row 1814 / 23680
# Processed row 1815 / 23680
# Processed row 1816 / 23680
# Processed row 1817 / 23680
# Processed row 1818 / 23680
# Processed row 1822 / 23680
# Processed row 1823 / 23680
# Processed row 1824 / 23680
# Processed row 1825 / 23680
# Processed row 1826 / 23680
# Processed row 1827 / 23680
# Processed row 1828 / 23680
# Processed row 1829 / 23680
# Processed row 1830 / 23680
# Processed row 1831 / 23680
# Processed row 1832 / 23680
# Processed row 1833 / 23680
# Processed row 1834 / 23680
# Processed row 1835 / 23680
# Processed row 1836 / 23680
# Processed row 1839 / 23680
# Processed row 1840 / 23680
# Processed row 1841 / 23680
# Processed row 1842 / 23680
# Processed row 1846 / 23680
# Processed row 1847 / 23680
# Processed row 1848 / 23680
# Processed row 1850 / 23680
# Processed row 1851 / 23680
# Processed row 1852 / 23680
# Processed row 1854 / 23680
# Processed row 1855 / 23680
# Processed row 1856 / 23680
# Processed row 1857 / 23680
# Processed row 1858 / 23680
# Processed row 1861 / 23680
# Processed row 1862 / 23680
# Processed row 1863 / 23680
# Processed row 1864 / 23680
# Processed row 1865 / 23680
# Processed row 1866 / 23680
# Processed row 1870 / 23680
# Processed row 1871 / 23680
# Processed row 1872 / 23680
# Processed row 1873 / 23680
# Processed row 1874 / 23680
# Processed row 1875 / 23680
# Processed row 1879 / 23680
# Processed row 1880 / 23680
# Processed row 1881 / 23680
# Processed row 1882 / 23680
# Processed row 1883 / 23680
# Processed row 1887 / 23680
# Processed row 1888 / 23680
# Processed row 1889 / 23680
# Processed row 1890 / 23680
# Processed row 1891 / 23680
# Processed row 1892 / 23680
# Processed row 1893 / 23680
# Processed row 1897 / 23680
# Processed row 1898 / 23680
# Processed row 1899 / 23680
# Processed row 1900 / 23680
# Processed row 1904 / 23680
# Processed row 1905 / 23680
# Processed row 1906 / 23680
# Processed row 1907 / 23680
# Processed row 1908 / 23680
# Processed row 1909 / 23680
# Processed row 1913 / 23680
# Processed row 1914 / 23680
# Processed row 1915 / 23680
# Processed row 1916 / 23680
# Processed row 1917 / 23680
# Processed row 1918 / 23680
# Processed row 1919 / 23680
# Processed row 1920 / 23680
# Processed row 1921 / 23680
# Processed row 1925 / 23680
# Processed row 1926 / 23680
# Processed row 1927 / 23680
# Processed row 1928 / 23680
# Processed row 1929 / 23680
# Processed row 1930 / 23680
# Processed row 1933 / 23680
# Processed row 1934 / 23680
# Processed row 1935 / 23680
# Processed row 1936 / 23680
# Processed row 1939 / 23680
# Processed row 1940 / 23680
# Processed row 1941 / 23680
# Processed row 1942 / 23680
# Processed row 1943 / 23680
# Processed row 1944 / 23680
# Processed row 1945 / 23680
# Processed row 1946 / 23680
# Processed row 1947 / 23680
# Processed row 1948 / 23680
# Processed row 1949 / 23680
# Processed row 1950 / 23680
# Processed row 1951 / 23680
# Processed row 1952 / 23680
# Processed row 1953 / 23680
# Processed row 1954 / 23680
# Processed row 1957 / 23680
# Processed row 1958 / 23680
# Processed row 1959 / 23680
# Processed row 1960 / 23680
# Processed row 1961 / 23680
# Processed row 1962 / 23680
# Processed row 1963 / 23680
# Processed row 1964 / 23680
# Processed row 1965 / 23680
# Processed row 1966 / 23680
# Processed row 1967 / 23680
# Processed row 1968 / 23680
# Processed row 1969 / 23680
# Processed row 1970 / 23680
# Processed row 1971 / 23680
# Processed row 1972 / 23680
# Processed row 1973 / 23680
# Processed row 1974 / 23680
# Processed row 1975 / 23680
# Processed row 1976 / 23680
# Processed row 1977 / 23680
# Processed row 1978 / 23680
# Processed row 1979 / 23680
# Processed row 1980 / 23680
# Processed row 1981 / 23680
# Processed row 1982 / 23680
# Processed row 1983 / 23680
# Processed row 1984 / 23680
# Processed row 1985 / 23680
# Processed row 1986 / 23680
# Processed row 1987 / 23680
# Processed row 1989 / 23680
# Processed row 1990 / 23680
# Processed row 1991 / 23680
# Processed row 1992 / 23680
# Processed row 1993 / 23680
# Processed row 1994 / 23680
# Processed row 1995 / 23680
# Processed row 1996 / 23680
# Processed row 1997 / 23680
# Processed row 2004 / 23680
# Processed row 2005 / 23680
# Processed row 2006 / 23680
# Processed row 2007 / 23680
# Processed row 2008 / 23680
# Processed row 2009 / 23680
# Processed row 2010 / 23680
# Processed row 2011 / 23680
# Processed row 2012 / 23680
# Processed row 2013 / 23680
# Processed row 2014 / 23680
# Processed row 2018 / 23680
# Processed row 2019 / 23680
# Processed row 2020 / 23680
# Processed row 2021 / 23680
# Processed row 2022 / 23680
# Processed row 2023 / 23680
# Processed row 2024 / 23680
# Processed row 2025 / 23680
# Processed row 2026 / 23680
# Processed row 2027 / 23680
# Processed row 2028 / 23680
# Processed row 2029 / 23680
# Processed row 2030 / 23680
# Processed row 2031 / 23680
# Processed row 2033 / 23680
# Processed row 2034 / 23680
# Processed row 2035 / 23680
# Processed row 2036 / 23680
# Processed row 2037 / 23680
# Processed row 2038 / 23680
# Processed row 2039 / 23680
# Processed row 2040 / 23680
# Processed row 2041 / 23680
# Processed row 2042 / 23680
# Processed row 2043 / 23680
# Processed row 2050 / 23680
# Processed row 2053 / 23680
# Processed row 2054 / 23680
# Processed row 2055 / 23680
# Processed row 2056 / 23680
# Processed row 2057 / 23680
# Processed row 2058 / 23680
# Processed row 2062 / 23680
# Processed row 2063 / 23680
# Processed row 2064 / 23680
# Processed row 2065 / 23680
# Processed row 2066 / 23680
# Processed row 2067 / 23680
# Processed row 2068 / 23680
# Processed row 2069 / 23680
# Processed row 2070 / 23680
# Processed row 2071 / 23680
# Processed row 2072 / 23680
# Processed row 2073 / 23680
# Processed row 2077 / 23680
# Processed row 2078 / 23680
# Processed row 2079 / 23680
# Processed row 2080 / 23680
# Processed row 2081 / 23680
# Processed row 2082 / 23680
# Processed row 2083 / 23680
# Processed row 2084 / 23680
# Processed row 2085 / 23680
# Processed row 2089 / 23680
# Processed row 2092 / 23680
# Processed row 2093 / 23680
# Processed row 2094 / 23680
# Processed row 2096 / 23680
# Processed row 2097 / 23680
# Processed row 2103 / 23680
# Processed row 2104 / 23680
# Processed row 2105 / 23680
# Processed row 2106 / 23680
# Processed row 2107 / 23680
# Processed row 2108 / 23680
# Processed row 2109 / 23680
# Processed row 2110 / 23680
# Processed row 2111 / 23680
# Processed row 2112 / 23680
# Processed row 2113 / 23680
# Processed row 2114 / 23680
# Processed row 2115 / 23680
# Processed row 2116 / 23680
# Processed row 2117 / 23680
# Processed row 2118 / 23680
# Processed row 2120 / 23680
# Processed row 2121 / 23680
# Processed row 2128 / 23680
# Processed row 2130 / 23680
# Processed row 2131 / 23680
# Processed row 2132 / 23680
# Processed row 2133 / 23680
# Processed row 2134 / 23680
# Processed row 2136 / 23680
# Processed row 2137 / 23680
# Processed row 2138 / 23680
# Processed row 2142 / 23680
# Processed row 2143 / 23680
# Processed row 2144 / 23680
# Processed row 2146 / 23680
# Processed row 2147 / 23680
# Processed row 2148 / 23680
# Processed row 2149 / 23680
# Processed row 2150 / 23680
# Processed row 2151 / 23680
# Processed row 2152 / 23680
# Processed row 2153 / 23680
# Processed row 2154 / 23680
# Processed row 2155 / 23680
# Processed row 2158 / 23680
# Processed row 2162 / 23680
# Processed row 2163 / 23680
# Processed row 2164 / 23680
# Processed row 2165 / 23680
# Processed row 2166 / 23680
# Processed row 2168 / 23680
# Processed row 2169 / 23680
# Processed row 2170 / 23680
# Processed row 2171 / 23680
# Processed row 2172 / 23680
# Processed row 2173 / 23680
# Processed row 2174 / 23680
# Processed row 2175 / 23680
# Processed row 2176 / 23680
# Processed row 2177 / 23680
# Processed row 2178 / 23680
# Processed row 2179 / 23680
# Processed row 2180 / 23680
# Processed row 2185 / 23680
# Processed row 2186 / 23680
# Processed row 2187 / 23680
# Processed row 2188 / 23680
# Processed row 2189 / 23680
# Processed row 2190 / 23680
# Processed row 2191 / 23680
# Processed row 2192 / 23680
# Processed row 2194 / 23680
# Processed row 2195 / 23680
# Processed row 2196 / 23680
# Processed row 2197 / 23680
# Processed row 2198 / 23680
# Processed row 2199 / 23680
# Processed row 2200 / 23680
# Processed row 2201 / 23680
# Processed row 2202 / 23680
# Processed row 2203 / 23680
# Processed row 2204 / 23680
# Processed row 2205 / 23680
# Processed row 2206 / 23680
# Processed row 2207 / 23680
# Processed row 2208 / 23680
# Processed row 2209 / 23680
# Processed row 2214 / 23680
# Processed row 2218 / 23680
# Processed row 2219 / 23680
# Processed row 2220 / 23680
# Processed row 2221 / 23680
# Processed row 2222 / 23680
# Processed row 2223 / 23680
# Processed row 2224 / 23680
# Processed row 2225 / 23680
# Processed row 2226 / 23680
# Processed row 2227 / 23680
# Processed row 2228 / 23680
# Processed row 2229 / 23680
# Processed row 2230 / 23680
# Processed row 2233 / 23680
# Processed row 2234 / 23680
# Processed row 2235 / 23680
# Processed row 2236 / 23680
# Processed row 2237 / 23680
# Processed row 2238 / 23680
# Processed row 2239 / 23680
# Processed row 2240 / 23680
# Processed row 2243 / 23680
# Processed row 2244 / 23680
# Processed row 2245 / 23680
# Processed row 2246 / 23680
# Processed row 2247 / 23680
# Processed row 2248 / 23680
# Processed row 2249 / 23680
# Processed row 2250 / 23680
# Processed row 2251 / 23680
# Processed row 2252 / 23680
# Processed row 2253 / 23680
# Processed row 2256 / 23680
# Processed row 2260 / 23680
# Processed row 2261 / 23680
# Processed row 2262 / 23680
# Processed row 2263 / 23680
# Processed row 2264 / 23680
# Processed row 2265 / 23680
# Processed row 2266 / 23680
# Processed row 2267 / 23680
# Processed row 2268 / 23680
# Processed row 2271 / 23680
# Processed row 2272 / 23680
# Processed row 2273 / 23680
# Processed row 2274 / 23680
# Processed row 2275 / 23680
# Processed row 2277 / 23680
# Processed row 2282 / 23680
# Processed row 2283 / 23680
# Processed row 2284 / 23680
# Processed row 2285 / 23680
# Processed row 2286 / 23680
# Processed row 2287 / 23680
# Processed row 2288 / 23680
# Processed row 2289 / 23680
# Processed row 2290 / 23680
# Processed row 2291 / 23680
# Processed row 2292 / 23680
# Processed row 2295 / 23680
# Processed row 2297 / 23680
# Processed row 2298 / 23680
# Processed row 2299 / 23680
# Processed row 2303 / 23680
# Processed row 2304 / 23680
# Processed row 2305 / 23680
# Processed row 2309 / 23680
# ...
# Processed row 22976 / 23680
# Processed row 22977 / 23680
# Processed row 22978 / 23680
# Processed row 22979 / 23680
# Processed row 22980 / 23680
# Processed row 22981 / 23680
# Processed row 22982 / 23680
# Processed row 22983 / 23680
# Processed row 22984 / 23680
# Processed row 22985 / 23680
# Processed row 22986 / 23680
# Processed row 22987 / 23680
# Processed row 22988 / 23680
# Processed row 22989 / 23680
# Processed row 22990 / 23680
# Processed row 22991 / 23680
# Processed row 22992 / 23680
# Processed row 22993 / 23680
# Processed row 22994 / 23680
# Processed row 22995 / 23680
# Processed row 22996 / 23680
# Processed row 22997 / 23680
# Processed row 22998 / 23680
# Processed row 22999 / 23680
# Processed row 23000 / 23680
# Processed row 23001 / 23680
# Processed row 23002 / 23680
# Processed row 23004 / 23680
# Processed row 23005 / 23680
# Processed row 23006 / 23680
# Processed row 23007 / 23680
# Processed row 23008 / 23680
# Processed row 23009 / 23680
# Processed row 23010 / 23680
# Processed row 23017 / 23680
# Processed row 23018 / 23680
# Processed row 23019 / 23680
# Processed row 23023 / 23680
# Processed row 23025 / 23680
# Processed row 23026 / 23680
# Processed row 23027 / 23680
# Processed row 23028 / 23680
# Processed row 23032 / 23680
# Processed row 23034 / 23680
# Processed row 23035 / 23680
# Processed row 23036 / 23680
# Processed row 23037 / 23680
# Processed row 23038 / 23680
# Processed row 23039 / 23680
# Processed row 23040 / 23680
# Processed row 23044 / 23680
# Processed row 23045 / 23680
# Processed row 23046 / 23680
# Processed row 23047 / 23680
# Processed row 23048 / 23680
# Processed row 23049 / 23680
# Processed row 23050 / 23680
# Processed row 23051 / 23680
# Processed row 23052 / 23680
# Processed row 23053 / 23680
# Processed row 23054 / 23680
# Processed row 23055 / 23680
# Processed row 23056 / 23680
# Processed row 23057 / 23680
# Processed row 23058 / 23680
# Processed row 23059 / 23680
# Processed row 23060 / 23680
# Processed row 23063 / 23680
# Processed row 23064 / 23680
# Processed row 23065 / 23680
# Processed row 23066 / 23680
# Processed row 23067 / 23680
# Processed row 23068 / 23680
# Processed row 23069 / 23680
# Processed row 23070 / 23680
# Processed row 23071 / 23680
# Processed row 23072 / 23680
# Processed row 23073 / 23680
# Processed row 23074 / 23680
# Processed row 23075 / 23680
# Processed row 23076 / 23680
# Processed row 23077 / 23680
# Processed row 23078 / 23680
# Processed row 23079 / 23680
# Processed row 23080 / 23680
# Processed row 23084 / 23680
# Processed row 23085 / 23680
# Processed row 23086 / 23680
# Processed row 23087 / 23680
# Processed row 23088 / 23680
# Processed row 23089 / 23680
# Processed row 23090 / 23680
# Processed row 23091 / 23680
# Processed row 23092 / 23680
# Processed row 23093 / 23680
# Processed row 23094 / 23680
# Processed row 23095 / 23680
# Processed row 23097 / 23680
# Processed row 23098 / 23680
# Processed row 23100 / 23680
# Processed row 23101 / 23680
# Processed row 23102 / 23680
# Processed row 23103 / 23680
# Processed row 23104 / 23680
# Processed row 23105 / 23680
# Processed row 23106 / 23680
# Processed row 23107 / 23680
# Processed row 23108 / 23680
# Processed row 23109 / 23680
# Processed row 23110 / 23680
# Processed row 23111 / 23680
# Processed row 23112 / 23680
# Processed row 23113 / 23680
# Processed row 23114 / 23680
# Processed row 23115 / 23680
# Processed row 23116 / 23680
# Processed row 23117 / 23680
# Processed row 23118 / 23680
# Processed row 23119 / 23680
# Processed row 23120 / 23680
# Processed row 23121 / 23680
# Processed row 23122 / 23680
# Processed row 23123 / 23680
# Processed row 23124 / 23680
# Processed row 23125 / 23680
# Processed row 23126 / 23680
# Processed row 23127 / 23680
# Processed row 23128 / 23680
# Processed row 23129 / 23680
# Processed row 23130 / 23680
# Processed row 23131 / 23680
# Processed row 23132 / 23680
# Processed row 23136 / 23680
# Processed row 23137 / 23680
# Processed row 23138 / 23680
# Processed row 23139 / 23680
# Processed row 23140 / 23680
# Processed row 23141 / 23680
# Processed row 23142 / 23680
# Processed row 23146 / 23680
# Processed row 23147 / 23680
# Processed row 23150 / 23680
# Processed row 23151 / 23680
# Processed row 23152 / 23680
# Processed row 23153 / 23680
# Processed row 23154 / 23680
# Processed row 23155 / 23680
# Processed row 23156 / 23680
# Processed row 23158 / 23680
# Processed row 23159 / 23680
# Processed row 23160 / 23680
# Processed row 23161 / 23680
# Processed row 23162 / 23680
# Processed row 23163 / 23680
# Processed row 23165 / 23680
# Processed row 23166 / 23680
# Processed row 23167 / 23680
# Processed row 23168 / 23680
# Processed row 23169 / 23680
# Processed row 23172 / 23680
# Processed row 23175 / 23680
# Processed row 23176 / 23680
# Processed row 23177 / 23680
# Processed row 23178 / 23680
# Processed row 23179 / 23680
# Processed row 23180 / 23680
# Processed row 23187 / 23680
# Processed row 23188 / 23680
# Processed row 23189 / 23680
# Processed row 23190 / 23680
# Processed row 23191 / 23680
# Processed row 23192 / 23680
# Processed row 23193 / 23680
# Processed row 23194 / 23680
# Processed row 23195 / 23680
# Processed row 23196 / 23680
# Processed row 23197 / 23680
# Processed row 23198 / 23680
# Processed row 23199 / 23680
# Processed row 23200 / 23680
# Processed row 23201 / 23680
# Processed row 23202 / 23680
# Processed row 23203 / 23680
# Processed row 23204 / 23680
# Processed row 23205 / 23680
# Processed row 23206 / 23680
# Processed row 23207 / 23680
# Processed row 23208 / 23680
# Processed row 23209 / 23680
# Processed row 23210 / 23680
# Processed row 23211 / 23680
# Processed row 23212 / 23680
# Processed row 23216 / 23680
# Processed row 23217 / 23680
# Processed row 23218 / 23680
# Processed row 23219 / 23680
# Processed row 23220 / 23680
# Processed row 23221 / 23680
# Processed row 23225 / 23680
# Processed row 23226 / 23680
# Processed row 23227 / 23680
# Processed row 23228 / 23680
# Processed row 23229 / 23680
# Processed row 23230 / 23680
# Processed row 23231 / 23680
# Processed row 23232 / 23680
# Processed row 23233 / 23680
# Processed row 23234 / 23680
# Processed row 23235 / 23680
# Processed row 23236 / 23680
# Processed row 23237 / 23680
# Processed row 23238 / 23680
# Processed row 23239 / 23680
# Processed row 23240 / 23680
# Processed row 23241 / 23680
# Processed row 23242 / 23680
# Processed row 23243 / 23680
# Processed row 23245 / 23680
# Processed row 23246 / 23680
# Processed row 23247 / 23680
# Processed row 23248 / 23680
# Processed row 23249 / 23680
# Processed row 23250 / 23680
# Processed row 23251 / 23680
# Processed row 23252 / 23680
# Processed row 23253 / 23680
# Processed row 23254 / 23680
# Processed row 23255 / 23680
# Processed row 23256 / 23680
# Processed row 23258 / 23680
# Processed row 23259 / 23680
# Processed row 23260 / 23680
# Processed row 23261 / 23680
# Processed row 23265 / 23680
# Processed row 23266 / 23680
# Processed row 23267 / 23680
# Processed row 23268 / 23680
# Processed row 23271 / 23680
# Processed row 23272 / 23680
# Processed row 23273 / 23680
# Processed row 23274 / 23680
# Processed row 23275 / 23680
# Processed row 23276 / 23680
# Processed row 23277 / 23680
# Processed row 23278 / 23680
# Processed row 23279 / 23680
# Processed row 23280 / 23680
# Processed row 23281 / 23680
# Processed row 23282 / 23680
# Processed row 23283 / 23680
# Processed row 23284 / 23680
# Processed row 23285 / 23680
# Processed row 23286 / 23680
# Processed row 23287 / 23680
# Processed row 23288 / 23680
# Processed row 23289 / 23680
# Processed row 23290 / 23680
# Processed row 23291 / 23680
# Processed row 23292 / 23680
# Processed row 23293 / 23680
# Processed row 23294 / 23680
# Processed row 23295 / 23680
# Processed row 23296 / 23680
# Processed row 23297 / 23680
# Processed row 23298 / 23680
# Processed row 23299 / 23680
# Processed row 23300 / 23680
# Processed row 23301 / 23680
# Processed row 23302 / 23680
# Processed row 23303 / 23680
# Processed row 23304 / 23680
# Processed row 23305 / 23680
# Processed row 23310 / 23680
# Processed row 23311 / 23680
# Processed row 23312 / 23680
# Processed row 23313 / 23680
# Processed row 23314 / 23680
# Processed row 23315 / 23680
# Processed row 23316 / 23680
# Processed row 23317 / 23680
# Processed row 23318 / 23680
# Processed row 23323 / 23680
# Processed row 23324 / 23680
# Processed row 23325 / 23680
# Processed row 23326 / 23680
# Processed row 23327 / 23680
# Processed row 23328 / 23680
# Processed row 23329 / 23680
# Processed row 23330 / 23680
# Processed row 23331 / 23680
# Processed row 23332 / 23680
# Processed row 23333 / 23680
# Processed row 23334 / 23680
# Processed row 23335 / 23680
# Processed row 23336 / 23680
# Processed row 23338 / 23680
# Processed row 23339 / 23680
# Processed row 23340 / 23680
# Processed row 23344 / 23680
# Processed row 23346 / 23680
# Processed row 23347 / 23680
# Processed row 23348 / 23680
# Processed row 23349 / 23680
# Processed row 23350 / 23680
# Processed row 23351 / 23680
# Processed row 23352 / 23680
# Processed row 23359 / 23680
# Processed row 23360 / 23680
# Processed row 23361 / 23680
# Processed row 23362 / 23680
# Processed row 23363 / 23680
# Processed row 23364 / 23680
# Processed row 23365 / 23680
# Processed row 23366 / 23680
# Processed row 23367 / 23680
# Processed row 23368 / 23680
# Processed row 23372 / 23680
# Processed row 23373 / 23680
# Processed row 23374 / 23680
# Processed row 23375 / 23680
# Processed row 23376 / 23680
# Processed row 23377 / 23680
# Processed row 23378 / 23680
# Processed row 23379 / 23680
# Processed row 23380 / 23680
# Processed row 23381 / 23680
# Processed row 23382 / 23680
# Processed row 23383 / 23680
# Processed row 23384 / 23680
# Processed row 23385 / 23680
# Processed row 23386 / 23680
# Processed row 23387 / 23680
# Processed row 23388 / 23680
# Processed row 23389 / 23680
# Processed row 23396 / 23680
# Processed row 23400 / 23680
# Processed row 23401 / 23680
# Processed row 23402 / 23680
# Processed row 23406 / 23680
# Processed row 23407 / 23680
# Processed row 23408 / 23680
# Processed row 23409 / 23680
# Processed row 23410 / 23680
# Processed row 23411 / 23680
# Processed row 23413 / 23680
# Processed row 23415 / 23680
# Processed row 23416 / 23680
# Processed row 23417 / 23680
# Processed row 23418 / 23680
# Processed row 23419 / 23680
# Processed row 23420 / 23680
# Processed row 23421 / 23680
# Processed row 23422 / 23680
# Processed row 23424 / 23680
# Processed row 23425 / 23680
# Processed row 23426 / 23680
# Processed row 23427 / 23680
# Processed row 23428 / 23680
# Processed row 23429 / 23680
# Processed row 23430 / 23680
# Processed row 23431 / 23680
# Processed row 23433 / 23680
# Processed row 23436 / 23680
# Processed row 23439 / 23680
# Processed row 23440 / 23680
# Processed row 23441 / 23680
# Processed row 23442 / 23680
# Processed row 23443 / 23680
# Processed row 23444 / 23680
# Processed row 23445 / 23680
# Processed row 23446 / 23680
# Processed row 23447 / 23680
# Processed row 23448 / 23680
# Processed row 23449 / 23680
# Processed row 23450 / 23680
# Processed row 23451 / 23680
# Processed row 23452 / 23680
# Processed row 23454 / 23680
# Processed row 23455 / 23680
# Processed row 23456 / 23680
# Processed row 23457 / 23680
# Processed row 23458 / 23680
# Processed row 23459 / 23680
# Processed row 23460 / 23680
# Processed row 23461 / 23680
# Processed row 23462 / 23680
# Processed row 23463 / 23680
# Processed row 23464 / 23680
# Processed row 23465 / 23680
# Processed row 23466 / 23680
# Processed row 23467 / 23680
# Processed row 23468 / 23680
# Processed row 23469 / 23680
# Processed row 23470 / 23680
# Processed row 23471 / 23680
# Processed row 23472 / 23680
# Processed row 23473 / 23680
# Processed row 23474 / 23680
# Processed row 23475 / 23680
# Processed row 23476 / 23680
# Processed row 23482 / 23680
# Processed row 23486 / 23680
# Processed row 23487 / 23680
# Processed row 23488 / 23680
# Processed row 23489 / 23680
# Processed row 23490 / 23680
# Processed row 23491 / 23680
# Processed row 23492 / 23680
# Processed row 23493 / 23680
# Processed row 23494 / 23680
# Processed row 23495 / 23680
# Processed row 23496 / 23680
# Processed row 23497 / 23680
# Processed row 23498 / 23680
# Processed row 23499 / 23680
# Processed row 23500 / 23680
# Processed row 23501 / 23680
# Processed row 23502 / 23680
# Processed row 23503 / 23680
# Processed row 23506 / 23680
# Processed row 23507 / 23680
# Processed row 23508 / 23680
# Processed row 23509 / 23680
# Processed row 23511 / 23680
# Processed row 23512 / 23680
# Processed row 23516 / 23680
# Processed row 23517 / 23680
# Processed row 23518 / 23680
# Processed row 23519 / 23680
# Processed row 23520 / 23680
# Processed row 23521 / 23680
# Processed row 23522 / 23680
# Processed row 23523 / 23680
# Processed row 23524 / 23680
# Processed row 23529 / 23680
# Processed row 23530 / 23680
# Processed row 23531 / 23680
# Processed row 23532 / 23680
# Processed row 23533 / 23680
# Processed row 23535 / 23680
# Processed row 23536 / 23680
# Processed row 23537 / 23680
# Processed row 23538 / 23680
# Processed row 23539 / 23680
# Processed row 23540 / 23680
# Processed row 23542 / 23680
# Processed row 23543 / 23680
# Processed row 23545 / 23680
# Processed row 23546 / 23680
# Processed row 23547 / 23680
# Processed row 23548 / 23680
# Processed row 23549 / 23680
# Processed row 23550 / 23680
# Processed row 23551 / 23680
# Processed row 23552 / 23680
# Processed row 23553 / 23680
# Processed row 23554 / 23680
# Processed row 23555 / 23680
# Processed row 23556 / 23680
# Processed row 23557 / 23680
# Processed row 23558 / 23680
# Processed row 23559 / 23680
# Processed row 23561 / 23680
# Processed row 23562 / 23680
# Processed row 23563 / 23680
# Processed row 23564 / 23680
# Processed row 23565 / 23680
# Processed row 23566 / 23680
# Processed row 23567 / 23680
# Processed row 23568 / 23680
# Processed row 23569 / 23680
# Processed row 23570 / 23680
# Processed row 23571 / 23680
# Processed row 23572 / 23680
# Processed row 23573 / 23680
# Processed row 23574 / 23680
# Processed row 23575 / 23680
# Processed row 23576 / 23680
# Processed row 23577 / 23680
# Processed row 23578 / 23680
# Processed row 23579 / 23680
# Processed row 23580 / 23680
# Processed row 23581 / 23680
# Processed row 23582 / 23680
# Processed row 23583 / 23680
# Processed row 23584 / 23680
# Processed row 23585 / 23680
# Processed row 23589 / 23680
# Processed row 23590 / 23680
# Processed row 23591 / 23680
# Processed row 23592 / 23680
# Processed row 23594 / 23680
# Processed row 23595 / 23680
# Processed row 23596 / 23680
# Processed row 23597 / 23680
# Processed row 23598 / 23680
# Processed row 23599 / 23680
# Processed row 23600 / 23680
# Processed row 23601 / 23680
# Processed row 23602 / 23680
# Processed row 23603 / 23680
# Processed row 23604 / 23680
# Processed row 23605 / 23680
# Processed row 23606 / 23680
# Processed row 23607 / 23680
# Processed row 23608 / 23680
# Processed row 23609 / 23680
# Processed row 23610 / 23680
# Processed row 23611 / 23680
# Processed row 23612 / 23680
# Processed row 23613 / 23680
# Processed row 23614 / 23680
# Processed row 23615 / 23680
# Processed row 23616 / 23680
# Processed row 23617 / 23680
# Processed row 23619 / 23680
# Processed row 23620 / 23680
# Processed row 23624 / 23680
# Processed row 23625 / 23680
# Processed row 23626 / 23680
# Processed row 23627 / 23680
# Processed row 23628 / 23680
# Processed row 23629 / 23680
# Processed row 23632 / 23680
# Processed row 23633 / 23680
# Processed row 23634 / 23680
# Processed row 23635 / 23680
# Processed row 23636 / 23680
# Processed row 23637 / 23680
# Processed row 23638 / 23680
# Processed row 23639 / 23680
# Processed row 23640 / 23680
# Processed row 23641 / 23680
# Processed row 23642 / 23680
# Processed row 23643 / 23680
# Processed row 23644 / 23680
# Processed row 23645 / 23680
# Processed row 23646 / 23680
# Processed row 23647 / 23680
# Processed row 23648 / 23680
# Processed row 23649 / 23680
# Processed row 23650 / 23680
# Processed row 23651 / 23680
# Processed row 23652 / 23680
# Processed row 23653 / 23680
# Processed row 23656 / 23680
# Processed row 23657 / 23680
# Processed row 23658 / 23680
# Processed row 23659 / 23680
# Processed row 23660 / 23680
# Processed row 23661 / 23680
# Processed row 23662 / 23680
# Processed row 23664 / 23680
# Processed row 23665 / 23680
# Processed row 23666 / 23680
# Processed row 23667 / 23680
# Processed row 23668 / 23680
# Processed row 23669 / 23680
# Processed row 23670 / 23680
# Processed row 23671 / 23680
# Processed row 23672 / 23680
# Processed row 23673 / 23680
# Processed row 23674 / 23680
# Processed row 23675 / 23680
# Processed row 23676 / 23680
# Processed row 23677 / 23680
# Processed row 23678 / 23680
# Processed row 23679 / 23680
# Processed row 23680 / 23680
#
# 최종 결과가 Final_Secondary_Stopover_Results.xlsx 파일로 저장되었습니다.

# %% [markdown]
# * 이전 코드 (map으로 시각적 확인용)

# %%
import plotly.express as px

def plot_route(main_logistics, first_stop, second_stop, warehouse_df):
    # 창고 위치에서 출발지 구하기
    warehouse_location = warehouse_df[warehouse_df["USER_ID"] == main_logistics["user_id"]].iloc[0]
    x0_start, y0_start = warehouse_location["location_lat"], warehouse_location["location_long"]
    
    routes = [
        {"lat": x0_start, "lon": y0_start, "name": "Main Start"},  # 출발지
        {"lat": main_logistics["destination_lat"], "lon": main_logistics["destination_long"], "name": "Main End"},  # 목적지
        {"lat": first_stop["logistics"]["destination_lat"], "lon": first_stop["logistics"]["destination_long"], "name": "First Stop"},
        {"lat": second_stop["logistics"]["destination_lat"], "lon": second_stop["logistics"]["destination_long"], "name": "Second Stop"},
    ]
    
    # 지도 시각화
    fig = px.scatter_mapbox(
        routes,
        lat="lat",
        lon="lon",
        hover_name="name",
        mapbox_style="open-street-map",
        zoom=5
    )
    fig.show()

# %%
def find_secondary_stop(main_route, first_stop, product_df, warehouse_df, radius, n=1):
    secondary_recommendations = []

    # 1차 경유지 도착지를 새로운 출발지로 설정
    first_stop_end_lat = first_stop["logistics"]["destination_lat"]
    first_stop_end_long = first_stop["logistics"]["destination_long"]

    # 원래 1차 물류의 최종 목적지
    main_route_dest_lat = main_route["destination_lat"]
    main_route_dest_long = main_route["destination_long"]

    for _, logistics in product_df.iterrows():
        # 물류의 창고 위치 찾기
        warehouse_location = warehouse_df[warehouse_df["USER_ID"] == logistics["user_id"]].iloc[0]
        x0_start, y0_start = warehouse_location["location_lat"], warehouse_location["location_long"]
        x0_end, y0_end = logistics["destination_lat"], logistics["destination_long"]

        # 출발지가 1차 경유지 도착지 반경 내에 있어야 함
        start_distance = calculate_distance(first_stop_end_lat, first_stop_end_long, x0_start, y0_start)
        end_distance = calculate_distance(x0_end, y0_end, main_route_dest_lat, main_route_dest_long)

        if start_distance <= radius and end_distance <= radius:
            # 방향이 일치하는지 확인
            if is_same_direction(
                first_stop_end_lat, first_stop_end_long,
                main_route_dest_lat, main_route_dest_long,
                x0_start, y0_start, x0_end, y0_end
            ):
                # 거리와 가격 계산
                distance_to_logistics = calculate_distance(x0_start, y0_start, x0_end, y0_end)
                price = calculate_shipping_cost(logistics["weight"], distance_to_logistics)

                normalized_distance = normalize(distance_to_logistics, 10, 400)
                normalized_price = normalize(price, 4, 70)

                # 기사의 선호도에 따른 가중치 조합
                distance_weight = 0.7
                price_weight = 1 - distance_weight

                score = (distance_weight * (1 - normalized_distance)) + (price_weight * normalized_price)

                # 추천 결과에 추가
                secondary_recommendations.append({
                    "logistics": logistics,
                    "score": score,
                    "price": price
                })

    # 상위 n개의 경유지 선택
    secondary_recommendations = sorted(
        secondary_recommendations, key=lambda l: l['score'], reverse=True
    )[:n]

    return secondary_recommendations

# 1차 추천 물류 기준으로 경유지 1~2차 경로 찾기
for main_logistics in recommended_logistics:
    print(f"\n1차 물류 경로: {main_logistics['product_id']} (출발지 -> 목적지)")
    
    # 1차 경유지 찾기
    first_stops = find_intermediate_logistics(main_logistics, product_df, warehouse_df, 50)
    if not first_stops:
        print("  - 1차 경유지 없음")
        continue

    first_stop = first_stops[0]  # 상위 1개 선택
    print(f"  1차 경유지: {first_stop['logistics']['product_id']} ("
          f"{first_stop['logistics']['departure']} -> {first_stop['logistics']['destination']})")

    # 2차 경유지 찾기
    second_stops = find_secondary_stop(main_logistics, first_stop, product_df, warehouse_df, 50)
    if not second_stops:
        print("  - 2차 경유지 없음")
        continue

    second_stop = second_stops[0]  # 상위 1개 선택
    print(f"  2차 경유지: {second_stop['logistics']['product_id']} ("
          f"{second_stop['logistics']['departure']} -> {second_stop['logistics']['destination']})")
# Out:
# 1차 물류 경로: 2723 (출발지 -> 목적지)
#   1차 경유지: 4317 (경기도 시흥시 만해로 43(정왕동) -> 경상북도 김천시 공단3길 94 (응명동))
#   2차 경유지: 3130 (대구광역시 서구 와룡로69길 7, 중리동1053 창고시설(삼화식품(주) 주건출물제1동 (중리동) -> 부산광역시 남구 우암로 165 (우암동, 동국보세장치장))
# <div>                            <div id="59eee345-5d7f-42db-8d29-ab9ba7cd70d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59eee345-5d7f-42db-8d29-ab9ba7cd70d5")) {                    Plotly.newPlot(                        "59eee345-5d7f-42db-8d29-ab9ba7cd70d5",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Main Start","Main End","First Stop","Second Stop"],"lat":[37.4464116,35.0891578,36.1510427,35.3193609],"legendgroup":"","lon":[126.6238096,128.7699,128.1299124,128.7416627],"marker":{"color":"#636efa"},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"ty ...

# %% [markdown]
# ### 최종 학습 데이터셋 완성

# %%
import pandas as pd

# 파일 로드
result_df = pd.read_excel("Temp_Result/Final_Secondary_Stopover_Results.xlsx")  # 결과 파일
product_df = pd.read_excel("Dataset/PRODUCT.xlsx")  # 물류 데이터
first_route_df = pd.read_excel("Temp_Result/First_Route.xlsx")  # 수정된 파일
input_df = pd.read_excel("INPUT.xlsx")  # departure_lat, departure_long을 가져올 파일

def get_lat_long_from_product(product_id, product_df):
    product_row = product_df[product_df["product_id"] == product_id]
    if not product_row.empty:
        departure_lat = product_row.iloc[0]["departure_lat"]
        departure_long = product_row.iloc[0]["departure_long"]
        destination_lat = product_row.iloc[0]["destination_lat"]
        destination_long = product_row.iloc[0]["destination_long"]
        return departure_lat, departure_long, destination_lat, destination_long
    return None, None, None, None  # 값이 없을 경우

def get_user_lat_long(user_id, product_id, first_route_df, input_df):
    # user_id와 product_id가 모두 일치하는 행을 first_route_df에서 찾음
    user_row = first_route_df[(first_route_df["user_id"] == user_id) & (first_route_df["product_id"] == product_id)]
    if not user_row.empty:
        # 입력 파일에서 departure_lat, departure_long 값 가져오기
        user_departure = user_row.iloc[0]["departure"]
        user_departure_lat = input_df[input_df["user_id"] == user_id].iloc[0]["departure_lat"]
        user_departure_long = input_df[input_df["user_id"] == user_id].iloc[0]["departure_long"]
        user_destination = user_row.iloc[0]["destination"]
        user_destination_lat = input_df[input_df["user_id"] == user_id].iloc[0]["destination_lat"]
        user_destination_long = input_df[input_df["user_id"] == user_id].iloc[0]["destination_long"]
        return user_departure, user_departure_lat, user_departure_long, user_destination, user_destination_lat, user_destination_long
    return None, None, None, None, None, None  # 값이 없을 경우

# 위경도 정보를 추가할 리스트 생성
enhanced_data = []

# Result 파일 처리
for _, row in result_df.iterrows():
    user_id = row["user_id"]
    main_product_id = row["main_product_id"]
    
    # 사용자 위치 위경도 (user_id와 main_product_id를 기준으로 매칭)
    user_departure, user_departure_lat, user_departure_long, user_destination, user_destination_lat, user_destination_long = get_user_lat_long(
        user_id, main_product_id, first_route_df, input_df
    )
    
    # Main Route 정보
    main_departure_lat, main_departure_long, main_destination_lat, main_destination_long = get_lat_long_from_product(
        row["main_product_id"], product_df
    )
    
    # First Stopover 정보
    first_departure_lat, first_departure_long, first_destination_lat, first_destination_long = get_lat_long_from_product(
        row["stopover_id"], product_df
    )
    
    # Second Stopover 정보
    second_departure_lat, second_departure_long, second_destination_lat, second_destination_long = get_lat_long_from_product(
        row["second_stop_id"], product_df
    )
    
    # 행 데이터 생성
    enhanced_data.append({
        "user_id": user_id,
        "user_departure": user_departure,
        "user_departure_lat": user_departure_lat,
        "user_departure_long": user_departure_long,
        "user_destination": user_destination,
        "user_destination_lat": user_destination_lat,
        "user_destination_long": user_destination_long,
        "main_product_id": row["main_product_id"],
        "main_departure": row["main_departure"],
        "main_departure_lat": main_departure_lat,
        "main_departure_long": main_departure_long,
        "main_destination": row["main_destination"],
        "main_destination_lat": main_destination_lat,
        "main_destination_long": main_destination_long,
        "first_stop_id": row["stopover_id"],
        "first_stopover_departure": row["stopover_departure"],
        "first_stopover_departure_lat": first_departure_lat,
        "first_stopover_departure_long": first_departure_long,
        "first_stopover_destination": row["stopover_destination"],
        "first_stopover_destination_lat": first_destination_lat,
        "first_stopover_destination_long": first_destination_long,
        "second_stop_id": row["second_stop_id"],
        "second_stopover_departure": row["second_stop_departure"],
        "second_stopover_departure_lat": second_departure_lat,
        "second_stopover_departure_long": second_departure_long,
        "second_stopover_destination": row["second_stop_destination"],
        "second_stopover_destination_lat": second_destination_lat,
        "second_stopover_destination_long": second_destination_long,
        "score": row["score"],
        "price": row["price"],
    })

# 결과를 데이터프레임으로 변환
enhanced_df = pd.DataFrame(enhanced_data)
enhanced_df = enhanced_df.dropna().reset_index(drop=True)


# 새로운 파일로 저장
enhanced_df.to_excel("Result.xlsx", index=False)
print("Result.xlsx 파일이 생성되었습니다.")
# Out:
# Result.xlsx 파일이 생성되었습니다.
